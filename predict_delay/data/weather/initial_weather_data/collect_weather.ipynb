# %% [markdown]
# ### 기상정보 취합 - 2024

# %%
import requests
import time
import pandas as pd
from datetime import datetime, timedelta

# API 기본 설정
API_URL = 'http://apis.data.go.kr/1360000/AirInfoService/getAirInfo'
PARAMS = {
    'numOfRows': '100',
    'pageNo': '1',
    'dataType': 'JSON',
    'icaoCode': 'RKSI'  # 인천공항
}
# API 인증키 추가 필요

# 시작 날짜 및 종료 날짜 설정
START_DATE = datetime(2024, 1, 1, 0, 0)
END_DATE = datetime(2024, 12, 31, 23, 0)

# 3시간 간격으로 시간 리스트 생성
def generate_time_list(start, end):
    time_list = []
    current_time = start
    while current_time <= end:
        time_list.append(current_time.strftime('%Y%m%d%H%M'))
        current_time += timedelta(hours=3)
    return time_list

time_points = generate_time_list(START_DATE, END_DATE)

# API 호출 실행
REQUEST_LIMIT = 10000  # 하루 요청 제한
requests_today = 0

# 데이터 저장 리스트
data_list = []

def fetch_weather_data(timestamp):
    global requests_today
    if requests_today >= REQUEST_LIMIT:
        print("일일 트래픽 제한 도달. 종료합니다.")
        return False
    
    PARAMS['fctm'] = timestamp
    try:
        response = requests.get(API_URL, params=PARAMS, timeout=10)
        response.raise_for_status()
        json_data = response.json()
        
        # JSON에서 필요한 데이터 추출
        for item in json_data.get('response', {}).get('body', {}).get('items', {}).get('item', []):
            data_list.append({
                'timestamp': item.get('tmFc', 'N/A'),
                'airport_name': bytes(item.get('airportName', ''), 'utf-8').decode('utf-8', 'ignore'),
                'wind_direction': item.get('wd', 'N/A'),
                'wind_speed': item.get('ws', 'N/A'),
                'temperature': item.get('ta', 'N/A'),
                'pressure': item.get('qnh', 'N/A')
            })
        
        print(f"{timestamp} 데이터 수집 완료.")
        requests_today += 1
    except requests.exceptions.RequestException as e:
        print(f"{timestamp} 데이터 요청 실패: {e}")
    
    return True

# 전체 데이터 수집
for timestamp in time_points:
    if not fetch_weather_data(timestamp):
        break
    time.sleep(1)  # 과부하 방지를 위한 대기

# 데이터 CSV 저장
if data_list:
    df = pd.DataFrame(data_list)
    df.to_csv('weather_data.csv', index=False, encoding='utf-8-sig')
    print("CSV 파일 저장 완료: weather_data.csv")
# Out:
# 202401010000 데이터 수집 완료.
# 202401010300 데이터 수집 완료.
# 202401010600 데이터 수집 완료.
# 202401010900 데이터 수집 완료.
# 202401011200 데이터 수집 완료.
# 202401011500 데이터 수집 완료.
# 202401011800 데이터 수집 완료.
# 202401012100 데이터 수집 완료.
# 202401020000 데이터 수집 완료.
# 202401020300 데이터 수집 완료.
# 202401020600 데이터 수집 완료.
# 202401020900 데이터 수집 완료.
# 202401021200 데이터 수집 완료.
# 202401021500 데이터 수집 완료.
# 202401021800 데이터 수집 완료.
# 202401022100 데이터 수집 완료.
# 202401030000 데이터 수집 완료.
# 202401030300 데이터 수집 완료.
# 202401030600 데이터 수집 완료.
# 202401030900 데이터 수집 완료.
# 202401031200 데이터 수집 완료.
# 202401031500 데이터 수집 완료.
# 202401031800 데이터 수집 완료.
# 202401032100 데이터 수집 완료.
# 202401040000 데이터 수집 완료.
# 202401040300 데이터 수집 완료.
# 202401040600 데이터 수집 완료.
# 202401040900 데이터 수집 완료.
# 202401041200 데이터 수집 완료.
# 202401041500 데이터 수집 완료.
# 202401041800 데이터 수집 완료.
# 202401042100 데이터 수집 완료.
# 202401050000 데이터 수집 완료.
# 202401050300 데이터 수집 완료.
# 202401050600 데이터 수집 완료.
# 202401050900 데이터 수집 완료.
# 202401051200 데이터 수집 완료.
# 202401051500 데이터 수집 완료.
# 202401051800 데이터 수집 완료.
# 202401052100 데이터 수집 완료.
# 202401060000 데이터 수집 완료.
# 202401060300 데이터 수집 완료.
# 202401060600 데이터 수집 완료.
# 202401060900 데이터 수집 완료.
# 202401061200 데이터 수집 완료.
# 202401061500 데이터 수집 완료.
# 202401061800 데이터 수집 완료.
# 202401062100 데이터 수집 완료.
# 202401070000 데이터 수집 완료.
# 202401070300 데이터 수집 완료.
# 202401070600 데이터 수집 완료.
# 202401070900 데이터 수집 완료.
# 202401071200 데이터 수집 완료.
# 202401071500 데이터 수집 완료.
# 202401071800 데이터 수집 완료.
# 202401072100 데이터 수집 완료.
# 202401080000 데이터 수집 완료.
# 202401080300 데이터 수집 완료.
# 202401080600 데이터 수집 완료.
# 202401080900 데이터 수집 완료.
# 202401081200 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202401081500 데이터 수집 완료.
# 202401081800 데이터 수집 완료.
# 202401082100 데이터 수집 완료.
# 202401090000 데이터 수집 완료.
# 202401090300 데이터 수집 완료.
# 202401090600 데이터 요청 실패: Expecting value: line 1 column 1 (char 0)
# 202401090900 데이터 수집 완료.
# 202401091200 데이터 수집 완료.
# 202401091500 데이터 수집 완료.
# 202401091800 데이터 수집 완료.
# 202401092100 데이터 수집 완료.
# 202401100000 데이터 수집 완료.
# 202401100300 데이터 수집 완료.
# 202401100600 데이터 수집 완료.
# 202401100900 데이터 수집 완료.
# 202401101200 데이터 수집 완료.
# 202401101500 데이터 수집 완료.
# 202401101800 데이터 수집 완료.
# 202401102100 데이터 수집 완료.
# 202401110000 데이터 수집 완료.
# 202401110300 데이터 수집 완료.
# 202401110600 데이터 수집 완료.
# 202401110900 데이터 수집 완료.
# 202401111200 데이터 수집 완료.
# 202401111500 데이터 수집 완료.
# 202401111800 데이터 수집 완료.
# 202401112100 데이터 수집 완료.
# 202401120000 데이터 수집 완료.
# 202401120300 데이터 수집 완료.
# 202401120600 데이터 수집 완료.
# 202401120900 데이터 수집 완료.
# 202401121200 데이터 수집 완료.
# 202401121500 데이터 수집 완료.
# 202401121800 데이터 수집 완료.
# 202401122100 데이터 수집 완료.
# 202401130000 데이터 수집 완료.
# 202401130300 데이터 수집 완료.
# 202401130600 데이터 수집 완료.
# 202401130900 데이터 수집 완료.
# 202401131200 데이터 수집 완료.
# 202401131500 데이터 수집 완료.
# 202401131800 데이터 수집 완료.
# 202401132100 데이터 수집 완료.
# 202401140000 데이터 수집 완료.
# 202401140300 데이터 수집 완료.
# 202401140600 데이터 수집 완료.
# 202401140900 데이터 수집 완료.
# 202401141200 데이터 수집 완료.
# 202401141500 데이터 수집 완료.
# 202401141800 데이터 수집 완료.
# 202401142100 데이터 수집 완료.
# 202401150000 데이터 수집 완료.
# 202401150300 데이터 수집 완료.
# 202401150600 데이터 수집 완료.
# 202401150900 데이터 수집 완료.
# 202401151200 데이터 수집 완료.
# 202401151500 데이터 수집 완료.
# 202401151800 데이터 수집 완료.
# 202401152100 데이터 수집 완료.
# 202401160000 데이터 수집 완료.
# 202401160300 데이터 수집 완료.
# 202401160600 데이터 수집 완료.
# 202401160900 데이터 수집 완료.
# 202401161200 데이터 수집 완료.
# 202401161500 데이터 수집 완료.
# 202401161800 데이터 수집 완료.
# 202401162100 데이터 수집 완료.
# 202401170000 데이터 수집 완료.
# 202401170300 데이터 수집 완료.
# 202401170600 데이터 수집 완료.
# 202401170900 데이터 수집 완료.
# 202401171200 데이터 수집 완료.
# 202401171500 데이터 수집 완료.
# 202401171800 데이터 수집 완료.
# 202401172100 데이터 수집 완료.
# 202401180000 데이터 수집 완료.
# 202401180300 데이터 수집 완료.
# 202401180600 데이터 수집 완료.
# 202401180900 데이터 수집 완료.
# 202401181200 데이터 수집 완료.
# 202401181500 데이터 수집 완료.
# 202401181800 데이터 수집 완료.
# 202401182100 데이터 수집 완료.
# 202401190000 데이터 수집 완료.
# 202401190300 데이터 수집 완료.
# 202401190600 데이터 수집 완료.
# 202401190900 데이터 수집 완료.
# 202401191200 데이터 수집 완료.
# 202401191500 데이터 수집 완료.
# 202401191800 데이터 수집 완료.
# 202401192100 데이터 수집 완료.
# 202401200000 데이터 수집 완료.
# 202401200300 데이터 수집 완료.
# 202401200600 데이터 수집 완료.
# 202401200900 데이터 수집 완료.
# 202401201200 데이터 수집 완료.
# 202401201500 데이터 수집 완료.
# 202401201800 데이터 수집 완료.
# 202401202100 데이터 수집 완료.
# 202401210000 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202401210300 데이터 수집 완료.
# 202401210600 데이터 수집 완료.
# 202401210900 데이터 수집 완료.
# 202401211200 데이터 수집 완료.
# 202401211500 데이터 수집 완료.
# 202401211800 데이터 수집 완료.
# 202401212100 데이터 수집 완료.
# 202401220000 데이터 수집 완료.
# 202401220300 데이터 수집 완료.
# 202401220600 데이터 수집 완료.
# 202401220900 데이터 수집 완료.
# 202401221200 데이터 수집 완료.
# 202401221500 데이터 수집 완료.
# 202401221800 데이터 수집 완료.
# 202401222100 데이터 수집 완료.
# 202401230000 데이터 수집 완료.
# 202401230300 데이터 수집 완료.
# 202401230600 데이터 수집 완료.
# 202401230900 데이터 수집 완료.
# 202401231200 데이터 수집 완료.
# 202401231500 데이터 수집 완료.
# 202401231800 데이터 수집 완료.
# 202401232100 데이터 수집 완료.
# 202401240000 데이터 수집 완료.
# 202401240300 데이터 수집 완료.
# 202401240600 데이터 수집 완료.
# 202401240900 데이터 수집 완료.
# 202401241200 데이터 수집 완료.
# 202401241500 데이터 수집 완료.
# 202401241800 데이터 수집 완료.
# 202401242100 데이터 수집 완료.
# 202401250000 데이터 수집 완료.
# 202401250300 데이터 수집 완료.
# 202401250600 데이터 수집 완료.
# 202401250900 데이터 수집 완료.
# 202401251200 데이터 수집 완료.
# 202401251500 데이터 수집 완료.
# 202401251800 데이터 수집 완료.
# 202401252100 데이터 수집 완료.
# 202401260000 데이터 수집 완료.
# 202401260300 데이터 수집 완료.
# 202401260600 데이터 수집 완료.
# 202401260900 데이터 수집 완료.
# 202401261200 데이터 수집 완료.
# 202401261500 데이터 수집 완료.
# 202401261800 데이터 수집 완료.
# 202401262100 데이터 수집 완료.
# 202401270000 데이터 수집 완료.
# 202401270300 데이터 수집 완료.
# 202401270600 데이터 수집 완료.
# 202401270900 데이터 수집 완료.
# 202401271200 데이터 수집 완료.
# 202401271500 데이터 수집 완료.
# 202401271800 데이터 수집 완료.
# 202401272100 데이터 수집 완료.
# 202401280000 데이터 수집 완료.
# 202401280300 데이터 수집 완료.
# 202401280600 데이터 수집 완료.
# 202401280900 데이터 수집 완료.
# 202401281200 데이터 수집 완료.
# 202401281500 데이터 수집 완료.
# 202401281800 데이터 수집 완료.
# 202401282100 데이터 수집 완료.
# 202401290000 데이터 수집 완료.
# 202401290300 데이터 수집 완료.
# 202401290600 데이터 수집 완료.
# 202401290900 데이터 수집 완료.
# 202401291200 데이터 수집 완료.
# 202401291500 데이터 수집 완료.
# 202401291800 데이터 수집 완료.
# 202401292100 데이터 수집 완료.
# 202401300000 데이터 수집 완료.
# 202401300300 데이터 수집 완료.
# 202401300600 데이터 수집 완료.
# 202401300900 데이터 수집 완료.
# 202401301200 데이터 수집 완료.
# 202401301500 데이터 수집 완료.
# 202401301800 데이터 수집 완료.
# 202401302100 데이터 수집 완료.
# 202401310000 데이터 수집 완료.
# 202401310300 데이터 수집 완료.
# 202401310600 데이터 수집 완료.
# 202401310900 데이터 수집 완료.
# 202401311200 데이터 수집 완료.
# 202401311500 데이터 수집 완료.
# 202401311800 데이터 수집 완료.
# 202401312100 데이터 수집 완료.
# 202402010000 데이터 수집 완료.
# 202402010300 데이터 수집 완료.
# 202402010600 데이터 수집 완료.
# 202402010900 데이터 수집 완료.
# 202402011200 데이터 수집 완료.
# 202402011500 데이터 수집 완료.
# 202402011800 데이터 수집 완료.
# 202402012100 데이터 수집 완료.
# 202402020000 데이터 수집 완료.
# 202402020300 데이터 수집 완료.
# 202402020600 데이터 수집 완료.
# 202402020900 데이터 수집 완료.
# 202402021200 데이터 수집 완료.
# 202402021500 데이터 수집 완료.
# 202402021800 데이터 수집 완료.
# 202402022100 데이터 수집 완료.
# 202402030000 데이터 수집 완료.
# 202402030300 데이터 수집 완료.
# 202402030600 데이터 수집 완료.
# 202402030900 데이터 수집 완료.
# 202402031200 데이터 수집 완료.
# 202402031500 데이터 수집 완료.
# 202402031800 데이터 수집 완료.
# 202402032100 데이터 수집 완료.
# 202402040000 데이터 수집 완료.
# 202402040300 데이터 수집 완료.
# 202402040600 데이터 수집 완료.
# 202402040900 데이터 수집 완료.
# 202402041200 데이터 수집 완료.
# 202402041500 데이터 수집 완료.
# 202402041800 데이터 수집 완료.
# 202402042100 데이터 수집 완료.
# 202402050000 데이터 수집 완료.
# 202402050300 데이터 수집 완료.
# 202402050600 데이터 수집 완료.
# 202402050900 데이터 수집 완료.
# 202402051200 데이터 수집 완료.
# 202402051500 데이터 수집 완료.
# 202402051800 데이터 수집 완료.
# 202402052100 데이터 수집 완료.
# 202402060000 데이터 수집 완료.
# 202402060300 데이터 수집 완료.
# 202402060600 데이터 수집 완료.
# 202402060900 데이터 수집 완료.
# 202402061200 데이터 수집 완료.
# 202402061500 데이터 수집 완료.
# 202402061800 데이터 수집 완료.
# 202402062100 데이터 수집 완료.
# 202402070000 데이터 수집 완료.
# 202402070300 데이터 수집 완료.
# 202402070600 데이터 수집 완료.
# 202402070900 데이터 수집 완료.
# 202402071200 데이터 수집 완료.
# 202402071500 데이터 수집 완료.
# 202402071800 데이터 수집 완료.
# 202402072100 데이터 수집 완료.
# 202402080000 데이터 수집 완료.
# 202402080300 데이터 수집 완료.
# 202402080600 데이터 수집 완료.
# 202402080900 데이터 수집 완료.
# 202402081200 데이터 수집 완료.
# 202402081500 데이터 수집 완료.
# 202402081800 데이터 수집 완료.
# 202402082100 데이터 수집 완료.
# 202402090000 데이터 수집 완료.
# 202402090300 데이터 수집 완료.
# 202402090600 데이터 수집 완료.
# 202402090900 데이터 수집 완료.
# 202402091200 데이터 수집 완료.
# 202402091500 데이터 수집 완료.
# 202402091800 데이터 수집 완료.
# 202402092100 데이터 수집 완료.
# 202402100000 데이터 수집 완료.
# 202402100300 데이터 수집 완료.
# 202402100600 데이터 수집 완료.
# 202402100900 데이터 수집 완료.
# 202402101200 데이터 수집 완료.
# 202402101500 데이터 수집 완료.
# 202402101800 데이터 수집 완료.
# 202402102100 데이터 수집 완료.
# 202402110000 데이터 수집 완료.
# 202402110300 데이터 수집 완료.
# 202402110600 데이터 수집 완료.
# 202402110900 데이터 수집 완료.
# 202402111200 데이터 수집 완료.
# 202402111500 데이터 수집 완료.
# 202402111800 데이터 수집 완료.
# 202402112100 데이터 수집 완료.
# 202402120000 데이터 수집 완료.
# 202402120300 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202402120600 데이터 수집 완료.
# 202402120900 데이터 수집 완료.
# 202402121200 데이터 수집 완료.
# 202402121500 데이터 수집 완료.
# 202402121800 데이터 수집 완료.
# 202402122100 데이터 수집 완료.
# 202402130000 데이터 수집 완료.
# 202402130300 데이터 수집 완료.
# 202402130600 데이터 수집 완료.
# 202402130900 데이터 수집 완료.
# 202402131200 데이터 수집 완료.
# 202402131500 데이터 수집 완료.
# 202402131800 데이터 수집 완료.
# 202402132100 데이터 수집 완료.
# 202402140000 데이터 수집 완료.
# 202402140300 데이터 수집 완료.
# 202402140600 데이터 수집 완료.
# 202402140900 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202402141200 데이터 수집 완료.
# 202402141500 데이터 수집 완료.
# 202402141800 데이터 수집 완료.
# 202402142100 데이터 수집 완료.
# 202402150000 데이터 수집 완료.
# 202402150300 데이터 수집 완료.
# 202402150600 데이터 수집 완료.
# 202402150900 데이터 수집 완료.
# 202402151200 데이터 수집 완료.
# 202402151500 데이터 수집 완료.
# 202402151800 데이터 수집 완료.
# 202402152100 데이터 수집 완료.
# 202402160000 데이터 수집 완료.
# 202402160300 데이터 수집 완료.
# 202402160600 데이터 수집 완료.
# 202402160900 데이터 수집 완료.
# 202402161200 데이터 수집 완료.
# 202402161500 데이터 수집 완료.
# 202402161800 데이터 수집 완료.
# 202402162100 데이터 수집 완료.
# 202402170000 데이터 수집 완료.
# 202402170300 데이터 수집 완료.
# 202402170600 데이터 수집 완료.
# 202402170900 데이터 수집 완료.
# 202402171200 데이터 수집 완료.
# 202402171500 데이터 수집 완료.
# 202402171800 데이터 수집 완료.
# 202402172100 데이터 수집 완료.
# 202402180000 데이터 수집 완료.
# 202402180300 데이터 수집 완료.
# 202402180600 데이터 수집 완료.
# 202402180900 데이터 수집 완료.
# 202402181200 데이터 수집 완료.
# 202402181500 데이터 수집 완료.
# 202402181800 데이터 수집 완료.
# 202402182100 데이터 수집 완료.
# 202402190000 데이터 수집 완료.
# 202402190300 데이터 수집 완료.
# 202402190600 데이터 수집 완료.
# 202402190900 데이터 수집 완료.
# 202402191200 데이터 수집 완료.
# 202402191500 데이터 수집 완료.
# 202402191800 데이터 수집 완료.
# 202402192100 데이터 수집 완료.
# 202402200000 데이터 수집 완료.
# 202402200300 데이터 수집 완료.
# 202402200600 데이터 수집 완료.
# 202402200900 데이터 수집 완료.
# 202402201200 데이터 수집 완료.
# 202402201500 데이터 수집 완료.
# 202402201800 데이터 수집 완료.
# 202402202100 데이터 수집 완료.
# 202402210000 데이터 수집 완료.
# 202402210300 데이터 수집 완료.
# 202402210600 데이터 수집 완료.
# 202402210900 데이터 수집 완료.
# 202402211200 데이터 수집 완료.
# 202402211500 데이터 수집 완료.
# 202402211800 데이터 수집 완료.
# 202402212100 데이터 수집 완료.
# 202402220000 데이터 수집 완료.
# 202402220300 데이터 수집 완료.
# 202402220600 데이터 수집 완료.
# 202402220900 데이터 수집 완료.
# 202402221200 데이터 수집 완료.
# 202402221500 데이터 수집 완료.
# 202402221800 데이터 수집 완료.
# 202402222100 데이터 수집 완료.
# 202402230000 데이터 수집 완료.
# 202402230300 데이터 수집 완료.
# 202402230600 데이터 수집 완료.
# 202402230900 데이터 수집 완료.
# 202402231200 데이터 수집 완료.
# 202402231500 데이터 수집 완료.
# 202402231800 데이터 수집 완료.
# 202402232100 데이터 수집 완료.
# 202402240000 데이터 수집 완료.
# 202402240300 데이터 수집 완료.
# 202402240600 데이터 수집 완료.
# 202402240900 데이터 수집 완료.
# 202402241200 데이터 수집 완료.
# 202402241500 데이터 수집 완료.
# 202402241800 데이터 수집 완료.
# 202402242100 데이터 수집 완료.
# 202402250000 데이터 수집 완료.
# 202402250300 데이터 수집 완료.
# 202402250600 데이터 수집 완료.
# 202402250900 데이터 수집 완료.
# 202402251200 데이터 수집 완료.
# 202402251500 데이터 수집 완료.
# 202402251800 데이터 수집 완료.
# 202402252100 데이터 수집 완료.
# 202402260000 데이터 수집 완료.
# 202402260300 데이터 수집 완료.
# 202402260600 데이터 수집 완료.
# 202402260900 데이터 수집 완료.
# 202402261200 데이터 수집 완료.
# 202402261500 데이터 수집 완료.
# 202402261800 데이터 수집 완료.
# 202402262100 데이터 수집 완료.
# 202402270000 데이터 수집 완료.
# 202402270300 데이터 수집 완료.
# 202402270600 데이터 수집 완료.
# 202402270900 데이터 수집 완료.
# 202402271200 데이터 수집 완료.
# 202402271500 데이터 수집 완료.
# 202402271800 데이터 수집 완료.
# 202402272100 데이터 수집 완료.
# 202402280000 데이터 수집 완료.
# 202402280300 데이터 수집 완료.
# 202402280600 데이터 수집 완료.
# 202402280900 데이터 수집 완료.
# 202402281200 데이터 수집 완료.
# 202402281500 데이터 수집 완료.
# 202402281800 데이터 수집 완료.
# 202402282100 데이터 수집 완료.
# 202402290000 데이터 수집 완료.
# 202402290300 데이터 수집 완료.
# 202402290600 데이터 수집 완료.
# 202402290900 데이터 수집 완료.
# 202402291200 데이터 수집 완료.
# 202402291500 데이터 수집 완료.
# 202402291800 데이터 수집 완료.
# 202402292100 데이터 수집 완료.
# 202403010000 데이터 수집 완료.
# 202403010300 데이터 수집 완료.
# 202403010600 데이터 수집 완료.
# 202403010900 데이터 수집 완료.
# 202403011200 데이터 수집 완료.
# 202403011500 데이터 수집 완료.
# 202403011800 데이터 수집 완료.
# 202403012100 데이터 수집 완료.
# 202403020000 데이터 수집 완료.
# 202403020300 데이터 수집 완료.
# 202403020600 데이터 수집 완료.
# 202403020900 데이터 수집 완료.
# 202403021200 데이터 수집 완료.
# 202403021500 데이터 수집 완료.
# 202403021800 데이터 수집 완료.
# 202403022100 데이터 수집 완료.
# 202403030000 데이터 수집 완료.
# 202403030300 데이터 수집 완료.
# 202403030600 데이터 수집 완료.
# 202403030900 데이터 수집 완료.
# 202403031200 데이터 수집 완료.
# 202403031500 데이터 수집 완료.
# 202403031800 데이터 수집 완료.
# 202403032100 데이터 수집 완료.
# 202403040000 데이터 수집 완료.
# 202403040300 데이터 수집 완료.
# 202403040600 데이터 수집 완료.
# 202403040900 데이터 수집 완료.
# 202403041200 데이터 수집 완료.
# 202403041500 데이터 수집 완료.
# 202403041800 데이터 수집 완료.
# 202403042100 데이터 수집 완료.
# 202403050000 데이터 수집 완료.
# 202403050300 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202403050600 데이터 수집 완료.
# 202403050900 데이터 수집 완료.
# 202403051200 데이터 수집 완료.
# 202403051500 데이터 수집 완료.
# 202403051800 데이터 수집 완료.
# 202403052100 데이터 수집 완료.
# 202403060000 데이터 수집 완료.
# 202403060300 데이터 수집 완료.
# 202403060600 데이터 수집 완료.
# 202403060900 데이터 수집 완료.
# 202403061200 데이터 수집 완료.
# 202403061500 데이터 수집 완료.
# 202403061800 데이터 수집 완료.
# 202403062100 데이터 수집 완료.
# 202403070000 데이터 수집 완료.
# 202403070300 데이터 수집 완료.
# 202403070600 데이터 수집 완료.
# 202403070900 데이터 수집 완료.
# 202403071200 데이터 수집 완료.
# 202403071500 데이터 수집 완료.
# 202403071800 데이터 수집 완료.
# 202403072100 데이터 수집 완료.
# 202403080000 데이터 수집 완료.
# 202403080300 데이터 수집 완료.
# 202403080600 데이터 수집 완료.
# 202403080900 데이터 수집 완료.
# 202403081200 데이터 수집 완료.
# 202403081500 데이터 수집 완료.
# 202403081800 데이터 수집 완료.
# 202403082100 데이터 수집 완료.
# 202403090000 데이터 수집 완료.
# 202403090300 데이터 수집 완료.
# 202403090600 데이터 수집 완료.
# 202403090900 데이터 수집 완료.
# 202403091200 데이터 수집 완료.
# 202403091500 데이터 수집 완료.
# 202403091800 데이터 수집 완료.
# 202403092100 데이터 수집 완료.
# 202403100000 데이터 수집 완료.
# 202403100300 데이터 수집 완료.
# 202403100600 데이터 수집 완료.
# 202403100900 데이터 수집 완료.
# 202403101200 데이터 수집 완료.
# 202403101500 데이터 수집 완료.
# 202403101800 데이터 수집 완료.
# 202403102100 데이터 수집 완료.
# 202403110000 데이터 수집 완료.
# 202403110300 데이터 수집 완료.
# 202403110600 데이터 수집 완료.
# 202403110900 데이터 수집 완료.
# 202403111200 데이터 수집 완료.
# 202403111500 데이터 수집 완료.
# 202403111800 데이터 수집 완료.
# 202403112100 데이터 수집 완료.
# 202403120000 데이터 수집 완료.
# 202403120300 데이터 수집 완료.
# 202403120600 데이터 수집 완료.
# 202403120900 데이터 수집 완료.
# 202403121200 데이터 수집 완료.
# 202403121500 데이터 수집 완료.
# 202403121800 데이터 수집 완료.
# 202403122100 데이터 수집 완료.
# 202403130000 데이터 수집 완료.
# 202403130300 데이터 수집 완료.
# 202403130600 데이터 수집 완료.
# 202403130900 데이터 수집 완료.
# 202403131200 데이터 수집 완료.
# 202403131500 데이터 수집 완료.
# 202403131800 데이터 수집 완료.
# 202403132100 데이터 수집 완료.
# 202403140000 데이터 수집 완료.
# 202403140300 데이터 수집 완료.
# 202403140600 데이터 수집 완료.
# 202403140900 데이터 수집 완료.
# 202403141200 데이터 수집 완료.
# 202403141500 데이터 수집 완료.
# 202403141800 데이터 수집 완료.
# 202403142100 데이터 수집 완료.
# 202403150000 데이터 수집 완료.
# 202403150300 데이터 수집 완료.
# 202403150600 데이터 수집 완료.
# 202403150900 데이터 수집 완료.
# 202403151200 데이터 수집 완료.
# 202403151500 데이터 수집 완료.
# 202403151800 데이터 수집 완료.
# 202403152100 데이터 수집 완료.
# 202403160000 데이터 수집 완료.
# 202403160300 데이터 수집 완료.
# 202403160600 데이터 수집 완료.
# 202403160900 데이터 수집 완료.
# 202403161200 데이터 수집 완료.
# 202403161500 데이터 수집 완료.
# 202403161800 데이터 수집 완료.
# 202403162100 데이터 수집 완료.
# 202403170000 데이터 수집 완료.
# 202403170300 데이터 수집 완료.
# 202403170600 데이터 수집 완료.
# 202403170900 데이터 수집 완료.
# 202403171200 데이터 수집 완료.
# 202403171500 데이터 수집 완료.
# 202403171800 데이터 수집 완료.
# 202403172100 데이터 수집 완료.
# 202403180000 데이터 수집 완료.
# 202403180300 데이터 수집 완료.
# 202403180600 데이터 수집 완료.
# 202403180900 데이터 수집 완료.
# 202403181200 데이터 수집 완료.
# 202403181500 데이터 수집 완료.
# 202403181800 데이터 수집 완료.
# 202403182100 데이터 수집 완료.
# 202403190000 데이터 수집 완료.
# 202403190300 데이터 수집 완료.
# 202403190600 데이터 수집 완료.
# 202403190900 데이터 수집 완료.
# 202403191200 데이터 수집 완료.
# 202403191500 데이터 수집 완료.
# 202403191800 데이터 수집 완료.
# 202403192100 데이터 수집 완료.
# 202403200000 데이터 수집 완료.
# 202403200300 데이터 수집 완료.
# 202403200600 데이터 수집 완료.
# 202403200900 데이터 수집 완료.
# 202403201200 데이터 수집 완료.
# 202403201500 데이터 수집 완료.
# 202403201800 데이터 수집 완료.
# 202403202100 데이터 수집 완료.
# 202403210000 데이터 수집 완료.
# 202403210300 데이터 수집 완료.
# 202403210600 데이터 수집 완료.
# 202403210900 데이터 수집 완료.
# 202403211200 데이터 수집 완료.
# 202403211500 데이터 수집 완료.
# 202403211800 데이터 수집 완료.
# 202403212100 데이터 수집 완료.
# 202403220000 데이터 수집 완료.
# 202403220300 데이터 수집 완료.
# 202403220600 데이터 수집 완료.
# 202403220900 데이터 수집 완료.
# 202403221200 데이터 수집 완료.
# 202403221500 데이터 수집 완료.
# 202403221800 데이터 수집 완료.
# 202403222100 데이터 수집 완료.
# 202403230000 데이터 수집 완료.
# 202403230300 데이터 수집 완료.
# 202403230600 데이터 수집 완료.
# 202403230900 데이터 수집 완료.
# 202403231200 데이터 수집 완료.
# 202403231500 데이터 수집 완료.
# 202403231800 데이터 수집 완료.
# 202403232100 데이터 수집 완료.
# 202403240000 데이터 수집 완료.
# 202403240300 데이터 수집 완료.
# 202403240600 데이터 수집 완료.
# 202403240900 데이터 수집 완료.
# 202403241200 데이터 수집 완료.
# 202403241500 데이터 수집 완료.
# 202403241800 데이터 수집 완료.
# 202403242100 데이터 수집 완료.
# 202403250000 데이터 수집 완료.
# 202403250300 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202403250600 데이터 수집 완료.
# 202403250900 데이터 수집 완료.
# 202403251200 데이터 수집 완료.
# 202403251500 데이터 수집 완료.
# 202403251800 데이터 수집 완료.
# 202403252100 데이터 수집 완료.
# 202403260000 데이터 수집 완료.
# 202403260300 데이터 수집 완료.
# 202403260600 데이터 수집 완료.
# 202403260900 데이터 수집 완료.
# 202403261200 데이터 수집 완료.
# 202403261500 데이터 수집 완료.
# 202403261800 데이터 수집 완료.
# 202403262100 데이터 수집 완료.
# 202403270000 데이터 수집 완료.
# 202403270300 데이터 수집 완료.
# 202403270600 데이터 수집 완료.
# 202403270900 데이터 수집 완료.
# 202403271200 데이터 수집 완료.
# 202403271500 데이터 수집 완료.
# 202403271800 데이터 수집 완료.
# 202403272100 데이터 수집 완료.
# 202403280000 데이터 수집 완료.
# 202403280300 데이터 수집 완료.
# 202403280600 데이터 수집 완료.
# 202403280900 데이터 수집 완료.
# 202403281200 데이터 수집 완료.
# 202403281500 데이터 수집 완료.
# 202403281800 데이터 수집 완료.
# 202403282100 데이터 수집 완료.
# 202403290000 데이터 수집 완료.
# 202403290300 데이터 수집 완료.
# 202403290600 데이터 수집 완료.
# 202403290900 데이터 수집 완료.
# 202403291200 데이터 수집 완료.
# 202403291500 데이터 수집 완료.
# 202403291800 데이터 수집 완료.
# 202403292100 데이터 수집 완료.
# 202403300000 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202403300300 데이터 수집 완료.
# 202403300600 데이터 수집 완료.
# 202403300900 데이터 수집 완료.
# 202403301200 데이터 수집 완료.
# 202403301500 데이터 수집 완료.
# 202403301800 데이터 수집 완료.
# 202403302100 데이터 수집 완료.
# 202403310000 데이터 수집 완료.
# 202403310300 데이터 수집 완료.
# 202403310600 데이터 수집 완료.
# 202403310900 데이터 수집 완료.
# 202403311200 데이터 수집 완료.
# 202403311500 데이터 수집 완료.
# 202403311800 데이터 수집 완료.
# 202403312100 데이터 수집 완료.
# 202404010000 데이터 수집 완료.
# 202404010300 데이터 수집 완료.
# 202404010600 데이터 수집 완료.
# 202404010900 데이터 수집 완료.
# 202404011200 데이터 수집 완료.
# 202404011500 데이터 수집 완료.
# 202404011800 데이터 수집 완료.
# 202404012100 데이터 수집 완료.
# 202404020000 데이터 수집 완료.
# 202404020300 데이터 수집 완료.
# 202404020600 데이터 수집 완료.
# 202404020900 데이터 수집 완료.
# 202404021200 데이터 수집 완료.
# 202404021500 데이터 수집 완료.
# 202404021800 데이터 수집 완료.
# 202404022100 데이터 수집 완료.
# 202404030000 데이터 수집 완료.
# 202404030300 데이터 수집 완료.
# 202404030600 데이터 수집 완료.
# 202404030900 데이터 수집 완료.
# 202404031200 데이터 수집 완료.
# 202404031500 데이터 수집 완료.
# 202404031800 데이터 수집 완료.
# 202404032100 데이터 수집 완료.
# 202404040000 데이터 수집 완료.
# 202404040300 데이터 수집 완료.
# 202404040600 데이터 수집 완료.
# 202404040900 데이터 수집 완료.
# 202404041200 데이터 수집 완료.
# 202404041500 데이터 수집 완료.
# 202404041800 데이터 수집 완료.
# 202404042100 데이터 수집 완료.
# 202404050000 데이터 수집 완료.
# 202404050300 데이터 수집 완료.
# 202404050600 데이터 수집 완료.
# 202404050900 데이터 수집 완료.
# 202404051200 데이터 수집 완료.
# 202404051500 데이터 수집 완료.
# 202404051800 데이터 수집 완료.
# 202404052100 데이터 수집 완료.
# 202404060000 데이터 수집 완료.
# 202404060300 데이터 수집 완료.
# 202404060600 데이터 수집 완료.
# 202404060900 데이터 수집 완료.
# 202404061200 데이터 수집 완료.
# 202404061500 데이터 수집 완료.
# 202404061800 데이터 수집 완료.
# 202404062100 데이터 수집 완료.
# 202404070000 데이터 수집 완료.
# 202404070300 데이터 수집 완료.
# 202404070600 데이터 수집 완료.
# 202404070900 데이터 수집 완료.
# 202404071200 데이터 수집 완료.
# 202404071500 데이터 수집 완료.
# 202404071800 데이터 수집 완료.
# 202404072100 데이터 수집 완료.
# 202404080000 데이터 수집 완료.
# 202404080300 데이터 수집 완료.
# 202404080600 데이터 수집 완료.
# 202404080900 데이터 수집 완료.
# 202404081200 데이터 수집 완료.
# 202404081500 데이터 수집 완료.
# 202404081800 데이터 수집 완료.
# 202404082100 데이터 수집 완료.
# 202404090000 데이터 수집 완료.
# 202404090300 데이터 수집 완료.
# 202404090600 데이터 수집 완료.
# 202404090900 데이터 수집 완료.
# 202404091200 데이터 수집 완료.
# 202404091500 데이터 수집 완료.
# 202404091800 데이터 수집 완료.
# 202404092100 데이터 수집 완료.
# 202404100000 데이터 수집 완료.
# 202404100300 데이터 수집 완료.
# 202404100600 데이터 수집 완료.
# 202404100900 데이터 수집 완료.
# 202404101200 데이터 수집 완료.
# 202404101500 데이터 수집 완료.
# 202404101800 데이터 수집 완료.
# 202404102100 데이터 수집 완료.
# 202404110000 데이터 수집 완료.
# 202404110300 데이터 수집 완료.
# 202404110600 데이터 수집 완료.
# 202404110900 데이터 수집 완료.
# 202404111200 데이터 수집 완료.
# 202404111500 데이터 수집 완료.
# 202404111800 데이터 수집 완료.
# 202404112100 데이터 수집 완료.
# 202404120000 데이터 수집 완료.
# 202404120300 데이터 수집 완료.
# 202404120600 데이터 수집 완료.
# 202404120900 데이터 수집 완료.
# 202404121200 데이터 수집 완료.
# 202404121500 데이터 수집 완료.
# 202404121800 데이터 수집 완료.
# 202404122100 데이터 수집 완료.
# 202404130000 데이터 수집 완료.
# 202404130300 데이터 수집 완료.
# 202404130600 데이터 수집 완료.
# 202404130900 데이터 수집 완료.
# 202404131200 데이터 수집 완료.
# 202404131500 데이터 수집 완료.
# 202404131800 데이터 수집 완료.
# 202404132100 데이터 수집 완료.
# 202404140000 데이터 수집 완료.
# 202404140300 데이터 수집 완료.
# 202404140600 데이터 수집 완료.
# 202404140900 데이터 수집 완료.
# 202404141200 데이터 수집 완료.
# 202404141500 데이터 수집 완료.
# 202404141800 데이터 수집 완료.
# 202404142100 데이터 수집 완료.
# 202404150000 데이터 수집 완료.
# 202404150300 데이터 수집 완료.
# 202404150600 데이터 수집 완료.
# 202404150900 데이터 수집 완료.
# 202404151200 데이터 수집 완료.
# 202404151500 데이터 수집 완료.
# 202404151800 데이터 수집 완료.
# 202404152100 데이터 수집 완료.
# 202404160000 데이터 수집 완료.
# 202404160300 데이터 수집 완료.
# 202404160600 데이터 수집 완료.
# 202404160900 데이터 수집 완료.
# 202404161200 데이터 수집 완료.
# 202404161500 데이터 수집 완료.
# 202404161800 데이터 수집 완료.
# 202404162100 데이터 수집 완료.
# 202404170000 데이터 수집 완료.
# 202404170300 데이터 수집 완료.
# 202404170600 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202404170900 데이터 수집 완료.
# 202404171200 데이터 수집 완료.
# 202404171500 데이터 수집 완료.
# 202404171800 데이터 수집 완료.
# 202404172100 데이터 수집 완료.
# 202404180000 데이터 수집 완료.
# 202404180300 데이터 수집 완료.
# 202404180600 데이터 수집 완료.
# 202404180900 데이터 수집 완료.
# 202404181200 데이터 수집 완료.
# 202404181500 데이터 수집 완료.
# 202404181800 데이터 수집 완료.
# 202404182100 데이터 수집 완료.
# 202404190000 데이터 수집 완료.
# 202404190300 데이터 수집 완료.
# 202404190600 데이터 수집 완료.
# 202404190900 데이터 수집 완료.
# 202404191200 데이터 수집 완료.
# 202404191500 데이터 수집 완료.
# 202404191800 데이터 수집 완료.
# 202404192100 데이터 수집 완료.
# 202404200000 데이터 수집 완료.
# 202404200300 데이터 수집 완료.
# 202404200600 데이터 수집 완료.
# 202404200900 데이터 수집 완료.
# 202404201200 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202404201500 데이터 수집 완료.
# 202404201800 데이터 수집 완료.
# 202404202100 데이터 수집 완료.
# 202404210000 데이터 수집 완료.
# 202404210300 데이터 수집 완료.
# 202404210600 데이터 수집 완료.
# 202404210900 데이터 수집 완료.
# 202404211200 데이터 수집 완료.
# 202404211500 데이터 수집 완료.
# 202404211800 데이터 수집 완료.
# 202404212100 데이터 수집 완료.
# 202404220000 데이터 수집 완료.
# 202404220300 데이터 수집 완료.
# 202404220600 데이터 수집 완료.
# 202404220900 데이터 수집 완료.
# 202404221200 데이터 수집 완료.
# 202404221500 데이터 수집 완료.
# 202404221800 데이터 수집 완료.
# 202404222100 데이터 수집 완료.
# 202404230000 데이터 수집 완료.
# 202404230300 데이터 수집 완료.
# 202404230600 데이터 수집 완료.
# 202404230900 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202404231200 데이터 수집 완료.
# 202404231500 데이터 수집 완료.
# 202404231800 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202404232100 데이터 수집 완료.
# 202404240000 데이터 수집 완료.
# 202404240300 데이터 수집 완료.
# 202404240600 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202404240900 데이터 수집 완료.
# 202404241200 데이터 수집 완료.
# 202404241500 데이터 수집 완료.
# 202404241800 데이터 수집 완료.
# 202404242100 데이터 수집 완료.
# 202404250000 데이터 수집 완료.
# 202404250300 데이터 수집 완료.
# 202404250600 데이터 수집 완료.
# 202404250900 데이터 수집 완료.
# 202404251200 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202404251500 데이터 수집 완료.
# 202404251800 데이터 수집 완료.
# 202404252100 데이터 수집 완료.
# 202404260000 데이터 수집 완료.
# 202404260300 데이터 수집 완료.
# 202404260600 데이터 수집 완료.
# 202404260900 데이터 수집 완료.
# 202404261200 데이터 수집 완료.
# 202404261500 데이터 수집 완료.
# 202404261800 데이터 수집 완료.
# 202404262100 데이터 수집 완료.
# 202404270000 데이터 수집 완료.
# 202404270300 데이터 수집 완료.
# 202404270600 데이터 수집 완료.
# 202404270900 데이터 수집 완료.
# 202404271200 데이터 수집 완료.
# 202404271500 데이터 수집 완료.
# 202404271800 데이터 수집 완료.
# 202404272100 데이터 수집 완료.
# 202404280000 데이터 수집 완료.
# 202404280300 데이터 수집 완료.
# 202404280600 데이터 수집 완료.
# 202404280900 데이터 수집 완료.
# 202404281200 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202404281500 데이터 수집 완료.
# 202404281800 데이터 수집 완료.
# 202404282100 데이터 수집 완료.
# 202404290000 데이터 수집 완료.
# 202404290300 데이터 수집 완료.
# 202404290600 데이터 수집 완료.
# 202404290900 데이터 수집 완료.
# 202404291200 데이터 수집 완료.
# 202404291500 데이터 수집 완료.
# 202404291800 데이터 수집 완료.
# 202404292100 데이터 수집 완료.
# 202404300000 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202404300300 데이터 수집 완료.
# 202404300600 데이터 수집 완료.
# 202404300900 데이터 수집 완료.
# 202404301200 데이터 수집 완료.
# 202404301500 데이터 수집 완료.
# 202404301800 데이터 수집 완료.
# 202404302100 데이터 수집 완료.
# 202405010000 데이터 수집 완료.
# 202405010300 데이터 수집 완료.
# 202405010600 데이터 수집 완료.
# 202405010900 데이터 수집 완료.
# 202405011200 데이터 수집 완료.
# 202405011500 데이터 수집 완료.
# 202405011800 데이터 수집 완료.
# 202405012100 데이터 수집 완료.
# 202405020000 데이터 수집 완료.
# 202405020300 데이터 수집 완료.
# 202405020600 데이터 수집 완료.
# 202405020900 데이터 수집 완료.
# 202405021200 데이터 수집 완료.
# 202405021500 데이터 수집 완료.
# 202405021800 데이터 수집 완료.
# 202405022100 데이터 수집 완료.
# 202405030000 데이터 수집 완료.
# 202405030300 데이터 수집 완료.
# 202405030600 데이터 수집 완료.
# 202405030900 데이터 수집 완료.
# 202405031200 데이터 수집 완료.
# 202405031500 데이터 수집 완료.
# 202405031800 데이터 수집 완료.
# 202405032100 데이터 수집 완료.
# 202405040000 데이터 수집 완료.
# 202405040300 데이터 수집 완료.
# 202405040600 데이터 수집 완료.
# 202405040900 데이터 수집 완료.
# 202405041200 데이터 수집 완료.
# 202405041500 데이터 수집 완료.
# 202405041800 데이터 수집 완료.
# 202405042100 데이터 수집 완료.
# 202405050000 데이터 수집 완료.
# 202405050300 데이터 수집 완료.
# 202405050600 데이터 수집 완료.
# 202405050900 데이터 수집 완료.
# 202405051200 데이터 수집 완료.
# 202405051500 데이터 수집 완료.
# 202405051800 데이터 수집 완료.
# 202405052100 데이터 수집 완료.
# 202405060000 데이터 수집 완료.
# 202405060300 데이터 수집 완료.
# 202405060600 데이터 수집 완료.
# 202405060900 데이터 수집 완료.
# 202405061200 데이터 수집 완료.
# 202405061500 데이터 수집 완료.
# 202405061800 데이터 수집 완료.
# 202405062100 데이터 수집 완료.
# 202405070000 데이터 수집 완료.
# 202405070300 데이터 수집 완료.
# 202405070600 데이터 수집 완료.
# 202405070900 데이터 수집 완료.
# 202405071200 데이터 수집 완료.
# 202405071500 데이터 수집 완료.
# 202405071800 데이터 수집 완료.
# 202405072100 데이터 수집 완료.
# 202405080000 데이터 수집 완료.
# 202405080300 데이터 수집 완료.
# 202405080600 데이터 수집 완료.
# 202405080900 데이터 수집 완료.
# 202405081200 데이터 수집 완료.
# 202405081500 데이터 수집 완료.
# 202405081800 데이터 수집 완료.
# 202405082100 데이터 수집 완료.
# 202405090000 데이터 수집 완료.
# 202405090300 데이터 수집 완료.
# 202405090600 데이터 수집 완료.
# 202405090900 데이터 수집 완료.
# 202405091200 데이터 수집 완료.
# 202405091500 데이터 수집 완료.
# 202405091800 데이터 수집 완료.
# 202405092100 데이터 수집 완료.
# 202405100000 데이터 수집 완료.
# 202405100300 데이터 수집 완료.
# 202405100600 데이터 수집 완료.
# 202405100900 데이터 수집 완료.
# 202405101200 데이터 수집 완료.
# 202405101500 데이터 수집 완료.
# 202405101800 데이터 수집 완료.
# 202405102100 데이터 수집 완료.
# 202405110000 데이터 수집 완료.
# 202405110300 데이터 수집 완료.
# 202405110600 데이터 수집 완료.
# 202405110900 데이터 수집 완료.
# 202405111200 데이터 수집 완료.
# 202405111500 데이터 수집 완료.
# 202405111800 데이터 수집 완료.
# 202405112100 데이터 수집 완료.
# 202405120000 데이터 수집 완료.
# 202405120300 데이터 수집 완료.
# 202405120600 데이터 수집 완료.
# 202405120900 데이터 수집 완료.
# 202405121200 데이터 수집 완료.
# 202405121500 데이터 수집 완료.
# 202405121800 데이터 수집 완료.
# 202405122100 데이터 수집 완료.
# 202405130000 데이터 수집 완료.
# 202405130300 데이터 수집 완료.
# 202405130600 데이터 수집 완료.
# 202405130900 데이터 수집 완료.
# 202405131200 데이터 수집 완료.
# 202405131500 데이터 수집 완료.
# 202405131800 데이터 수집 완료.
# 202405132100 데이터 수집 완료.
# 202405140000 데이터 수집 완료.
# 202405140300 데이터 수집 완료.
# 202405140600 데이터 수집 완료.
# 202405140900 데이터 수집 완료.
# 202405141200 데이터 수집 완료.
# 202405141500 데이터 수집 완료.
# 202405141800 데이터 수집 완료.
# 202405142100 데이터 수집 완료.
# 202405150000 데이터 수집 완료.
# 202405150300 데이터 수집 완료.
# 202405150600 데이터 수집 완료.
# 202405150900 데이터 수집 완료.
# 202405151200 데이터 수집 완료.
# 202405151500 데이터 수집 완료.
# 202405151800 데이터 수집 완료.
# 202405152100 데이터 수집 완료.
# 202405160000 데이터 수집 완료.
# 202405160300 데이터 수집 완료.
# 202405160600 데이터 수집 완료.
# 202405160900 데이터 수집 완료.
# 202405161200 데이터 수집 완료.
# 202405161500 데이터 수집 완료.
# 202405161800 데이터 수집 완료.
# 202405162100 데이터 수집 완료.
# 202405170000 데이터 수집 완료.
# 202405170300 데이터 수집 완료.
# 202405170600 데이터 수집 완료.
# 202405170900 데이터 수집 완료.
# 202405171200 데이터 수집 완료.
# 202405171500 데이터 수집 완료.
# 202405171800 데이터 수집 완료.
# 202405172100 데이터 수집 완료.
# 202405180000 데이터 수집 완료.
# 202405180300 데이터 수집 완료.
# 202405180600 데이터 수집 완료.
# 202405180900 데이터 수집 완료.
# 202405181200 데이터 수집 완료.
# 202405181500 데이터 수집 완료.
# 202405181800 데이터 수집 완료.
# 202405182100 데이터 수집 완료.
# 202405190000 데이터 수집 완료.
# 202405190300 데이터 수집 완료.
# 202405190600 데이터 수집 완료.
# 202405190900 데이터 수집 완료.
# 202405191200 데이터 수집 완료.
# 202405191500 데이터 수집 완료.
# 202405191800 데이터 수집 완료.
# 202405192100 데이터 수집 완료.
# 202405200000 데이터 수집 완료.
# 202405200300 데이터 수집 완료.
# 202405200600 데이터 수집 완료.
# 202405200900 데이터 수집 완료.
# 202405201200 데이터 수집 완료.
# 202405201500 데이터 수집 완료.
# 202405201800 데이터 수집 완료.
# 202405202100 데이터 수집 완료.
# 202405210000 데이터 수집 완료.
# 202405210300 데이터 수집 완료.
# 202405210600 데이터 수집 완료.
# 202405210900 데이터 수집 완료.
# 202405211200 데이터 수집 완료.
# 202405211500 데이터 수집 완료.
# 202405211800 데이터 수집 완료.
# 202405212100 데이터 수집 완료.
# 202405220000 데이터 수집 완료.
# 202405220300 데이터 수집 완료.
# 202405220600 데이터 수집 완료.
# 202405220900 데이터 수집 완료.
# 202405221200 데이터 수집 완료.
# 202405221500 데이터 수집 완료.
# 202405221800 데이터 수집 완료.
# 202405222100 데이터 수집 완료.
# 202405230000 데이터 수집 완료.
# 202405230300 데이터 수집 완료.
# 202405230600 데이터 수집 완료.
# 202405230900 데이터 수집 완료.
# 202405231200 데이터 수집 완료.
# 202405231500 데이터 수집 완료.
# 202405231800 데이터 수집 완료.
# 202405232100 데이터 수집 완료.
# 202405240000 데이터 수집 완료.
# 202405240300 데이터 수집 완료.
# 202405240600 데이터 수집 완료.
# 202405240900 데이터 수집 완료.
# 202405241200 데이터 수집 완료.
# 202405241500 데이터 수집 완료.
# 202405241800 데이터 수집 완료.
# 202405242100 데이터 수집 완료.
# 202405250000 데이터 수집 완료.
# 202405250300 데이터 수집 완료.
# 202405250600 데이터 수집 완료.
# 202405250900 데이터 수집 완료.
# 202405251200 데이터 수집 완료.
# 202405251500 데이터 수집 완료.
# 202405251800 데이터 수집 완료.
# 202405252100 데이터 수집 완료.
# 202405260000 데이터 수집 완료.
# 202405260300 데이터 수집 완료.
# 202405260600 데이터 수집 완료.
# 202405260900 데이터 수집 완료.
# 202405261200 데이터 수집 완료.
# 202405261500 데이터 수집 완료.
# 202405261800 데이터 수집 완료.
# 202405262100 데이터 수집 완료.
# 202405270000 데이터 수집 완료.
# 202405270300 데이터 수집 완료.
# 202405270600 데이터 수집 완료.
# 202405270900 데이터 수집 완료.
# 202405271200 데이터 수집 완료.
# 202405271500 데이터 수집 완료.
# 202405271800 데이터 수집 완료.
# 202405272100 데이터 수집 완료.
# 202405280000 데이터 수집 완료.
# 202405280300 데이터 수집 완료.
# 202405280600 데이터 수집 완료.
# 202405280900 데이터 수집 완료.
# 202405281200 데이터 수집 완료.
# 202405281500 데이터 수집 완료.
# 202405281800 데이터 수집 완료.
# 202405282100 데이터 수집 완료.
# 202405290000 데이터 수집 완료.
# 202405290300 데이터 수집 완료.
# 202405290600 데이터 수집 완료.
# 202405290900 데이터 수집 완료.
# 202405291200 데이터 수집 완료.
# 202405291500 데이터 수집 완료.
# 202405291800 데이터 수집 완료.
# 202405292100 데이터 수집 완료.
# 202405300000 데이터 수집 완료.
# 202405300300 데이터 수집 완료.
# 202405300600 데이터 수집 완료.
# 202405300900 데이터 수집 완료.
# 202405301200 데이터 수집 완료.
# 202405301500 데이터 수집 완료.
# 202405301800 데이터 수집 완료.
# 202405302100 데이터 수집 완료.
# 202405310000 데이터 수집 완료.
# 202405310300 데이터 수집 완료.
# 202405310600 데이터 수집 완료.
# 202405310900 데이터 수집 완료.
# 202405311200 데이터 수집 완료.
# 202405311500 데이터 수집 완료.
# 202405311800 데이터 수집 완료.
# 202405312100 데이터 수집 완료.
# 202406010000 데이터 수집 완료.
# 202406010300 데이터 수집 완료.
# 202406010600 데이터 수집 완료.
# 202406010900 데이터 수집 완료.
# 202406011200 데이터 수집 완료.
# 202406011500 데이터 수집 완료.
# 202406011800 데이터 수집 완료.
# 202406012100 데이터 수집 완료.
# 202406020000 데이터 수집 완료.
# 202406020300 데이터 수집 완료.
# 202406020600 데이터 수집 완료.
# 202406020900 데이터 수집 완료.
# 202406021200 데이터 수집 완료.
# 202406021500 데이터 수집 완료.
# 202406021800 데이터 수집 완료.
# 202406022100 데이터 수집 완료.
# 202406030000 데이터 수집 완료.
# 202406030300 데이터 수집 완료.
# 202406030600 데이터 수집 완료.
# 202406030900 데이터 수집 완료.
# 202406031200 데이터 수집 완료.
# 202406031500 데이터 수집 완료.
# 202406031800 데이터 수집 완료.
# 202406032100 데이터 수집 완료.
# 202406040000 데이터 수집 완료.
# 202406040300 데이터 수집 완료.
# 202406040600 데이터 수집 완료.
# 202406040900 데이터 수집 완료.
# 202406041200 데이터 수집 완료.
# 202406041500 데이터 수집 완료.
# 202406041800 데이터 수집 완료.
# 202406042100 데이터 수집 완료.
# 202406050000 데이터 수집 완료.
# 202406050300 데이터 수집 완료.
# 202406050600 데이터 수집 완료.
# 202406050900 데이터 수집 완료.
# 202406051200 데이터 수집 완료.
# 202406051500 데이터 수집 완료.
# 202406051800 데이터 수집 완료.
# 202406052100 데이터 수집 완료.
# 202406060000 데이터 수집 완료.
# 202406060300 데이터 수집 완료.
# 202406060600 데이터 수집 완료.
# 202406060900 데이터 수집 완료.
# 202406061200 데이터 수집 완료.
# 202406061500 데이터 수집 완료.
# 202406061800 데이터 수집 완료.
# 202406062100 데이터 수집 완료.
# 202406070000 데이터 수집 완료.
# 202406070300 데이터 수집 완료.
# 202406070600 데이터 수집 완료.
# 202406070900 데이터 수집 완료.
# 202406071200 데이터 수집 완료.
# 202406071500 데이터 수집 완료.
# 202406071800 데이터 수집 완료.
# 202406072100 데이터 수집 완료.
# 202406080000 데이터 수집 완료.
# 202406080300 데이터 수집 완료.
# 202406080600 데이터 수집 완료.
# 202406080900 데이터 수집 완료.
# 202406081200 데이터 수집 완료.
# 202406081500 데이터 수집 완료.
# 202406081800 데이터 수집 완료.
# 202406082100 데이터 수집 완료.
# 202406090000 데이터 수집 완료.
# 202406090300 데이터 수집 완료.
# 202406090600 데이터 수집 완료.
# 202406090900 데이터 수집 완료.
# 202406091200 데이터 수집 완료.
# 202406091500 데이터 수집 완료.
# 202406091800 데이터 수집 완료.
# 202406092100 데이터 수집 완료.
# 202406100000 데이터 수집 완료.
# 202406100300 데이터 수집 완료.
# 202406100600 데이터 수집 완료.
# 202406100900 데이터 수집 완료.
# 202406101200 데이터 수집 완료.
# 202406101500 데이터 수집 완료.
# 202406101800 데이터 수집 완료.
# 202406102100 데이터 수집 완료.
# 202406110000 데이터 수집 완료.
# 202406110300 데이터 수집 완료.
# 202406110600 데이터 수집 완료.
# 202406110900 데이터 수집 완료.
# 202406111200 데이터 수집 완료.
# 202406111500 데이터 수집 완료.
# 202406111800 데이터 수집 완료.
# 202406112100 데이터 수집 완료.
# 202406120000 데이터 수집 완료.
# 202406120300 데이터 수집 완료.
# 202406120600 데이터 수집 완료.
# 202406120900 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202406121200 데이터 수집 완료.
# 202406121500 데이터 수집 완료.
# 202406121800 데이터 수집 완료.
# 202406122100 데이터 수집 완료.
# 202406130000 데이터 수집 완료.
# 202406130300 데이터 수집 완료.
# 202406130600 데이터 수집 완료.
# 202406130900 데이터 수집 완료.
# 202406131200 데이터 수집 완료.
# 202406131500 데이터 수집 완료.
# 202406131800 데이터 수집 완료.
# 202406132100 데이터 수집 완료.
# 202406140000 데이터 수집 완료.
# 202406140300 데이터 수집 완료.
# 202406140600 데이터 수집 완료.
# 202406140900 데이터 수집 완료.
# 202406141200 데이터 수집 완료.
# 202406141500 데이터 수집 완료.
# 202406141800 데이터 수집 완료.
# 202406142100 데이터 수집 완료.
# 202406150000 데이터 수집 완료.
# 202406150300 데이터 수집 완료.
# 202406150600 데이터 수집 완료.
# 202406150900 데이터 수집 완료.
# 202406151200 데이터 수집 완료.
# 202406151500 데이터 수집 완료.
# 202406151800 데이터 수집 완료.
# 202406152100 데이터 수집 완료.
# 202406160000 데이터 수집 완료.
# 202406160300 데이터 수집 완료.
# 202406160600 데이터 수집 완료.
# 202406160900 데이터 수집 완료.
# 202406161200 데이터 수집 완료.
# 202406161500 데이터 수집 완료.
# 202406161800 데이터 수집 완료.
# 202406162100 데이터 수집 완료.
# 202406170000 데이터 수집 완료.
# 202406170300 데이터 수집 완료.
# 202406170600 데이터 수집 완료.
# 202406170900 데이터 수집 완료.
# 202406171200 데이터 수집 완료.
# 202406171500 데이터 수집 완료.
# 202406171800 데이터 수집 완료.
# 202406172100 데이터 수집 완료.
# 202406180000 데이터 수집 완료.
# 202406180300 데이터 수집 완료.
# 202406180600 데이터 수집 완료.
# 202406180900 데이터 수집 완료.
# 202406181200 데이터 수집 완료.
# 202406181500 데이터 수집 완료.
# 202406181800 데이터 수집 완료.
# 202406182100 데이터 수집 완료.
# 202406190000 데이터 수집 완료.
# 202406190300 데이터 수집 완료.
# 202406190600 데이터 수집 완료.
# 202406190900 데이터 수집 완료.
# 202406191200 데이터 수집 완료.
# 202406191500 데이터 수집 완료.
# 202406191800 데이터 수집 완료.
# 202406192100 데이터 수집 완료.
# 202406200000 데이터 수집 완료.
# 202406200300 데이터 수집 완료.
# 202406200600 데이터 수집 완료.
# 202406200900 데이터 수집 완료.
# 202406201200 데이터 수집 완료.
# 202406201500 데이터 수집 완료.
# 202406201800 데이터 수집 완료.
# 202406202100 데이터 수집 완료.
# 202406210000 데이터 수집 완료.
# 202406210300 데이터 수집 완료.
# 202406210600 데이터 수집 완료.
# 202406210900 데이터 수집 완료.
# 202406211200 데이터 수집 완료.
# 202406211500 데이터 수집 완료.
# 202406211800 데이터 수집 완료.
# 202406212100 데이터 수집 완료.
# 202406220000 데이터 수집 완료.
# 202406220300 데이터 수집 완료.
# 202406220600 데이터 수집 완료.
# 202406220900 데이터 수집 완료.
# 202406221200 데이터 수집 완료.
# 202406221500 데이터 수집 완료.
# 202406221800 데이터 수집 완료.
# 202406222100 데이터 수집 완료.
# 202406230000 데이터 수집 완료.
# 202406230300 데이터 수집 완료.
# 202406230600 데이터 수집 완료.
# 202406230900 데이터 수집 완료.
# 202406231200 데이터 수집 완료.
# 202406231500 데이터 수집 완료.
# 202406231800 데이터 수집 완료.
# 202406232100 데이터 수집 완료.
# 202406240000 데이터 수집 완료.
# 202406240300 데이터 수집 완료.
# 202406240600 데이터 수집 완료.
# 202406240900 데이터 수집 완료.
# 202406241200 데이터 수집 완료.
# 202406241500 데이터 수집 완료.
# 202406241800 데이터 수집 완료.
# 202406242100 데이터 수집 완료.
# 202406250000 데이터 수집 완료.
# 202406250300 데이터 수집 완료.
# 202406250600 데이터 수집 완료.
# 202406250900 데이터 수집 완료.
# 202406251200 데이터 수집 완료.
# 202406251500 데이터 수집 완료.
# 202406251800 데이터 수집 완료.
# 202406252100 데이터 수집 완료.
# 202406260000 데이터 수집 완료.
# 202406260300 데이터 수집 완료.
# 202406260600 데이터 수집 완료.
# 202406260900 데이터 수집 완료.
# 202406261200 데이터 수집 완료.
# 202406261500 데이터 수집 완료.
# 202406261800 데이터 수집 완료.
# 202406262100 데이터 수집 완료.
# 202406270000 데이터 수집 완료.
# 202406270300 데이터 수집 완료.
# 202406270600 데이터 수집 완료.
# 202406270900 데이터 수집 완료.
# 202406271200 데이터 수집 완료.
# 202406271500 데이터 수집 완료.
# 202406271800 데이터 수집 완료.
# 202406272100 데이터 수집 완료.
# 202406280000 데이터 수집 완료.
# 202406280300 데이터 수집 완료.
# 202406280600 데이터 수집 완료.
# 202406280900 데이터 수집 완료.
# 202406281200 데이터 수집 완료.
# 202406281500 데이터 수집 완료.
# 202406281800 데이터 수집 완료.
# 202406282100 데이터 수집 완료.
# 202406290000 데이터 수집 완료.
# 202406290300 데이터 수집 완료.
# 202406290600 데이터 수집 완료.
# 202406290900 데이터 수집 완료.
# 202406291200 데이터 수집 완료.
# 202406291500 데이터 수집 완료.
# 202406291800 데이터 수집 완료.
# 202406292100 데이터 수집 완료.
# 202406300000 데이터 수집 완료.
# 202406300300 데이터 수집 완료.
# 202406300600 데이터 수집 완료.
# 202406300900 데이터 수집 완료.
# 202406301200 데이터 수집 완료.
# 202406301500 데이터 수집 완료.
# 202406301800 데이터 수집 완료.
# 202406302100 데이터 수집 완료.
# 202407010000 데이터 수집 완료.
# 202407010300 데이터 수집 완료.
# 202407010600 데이터 수집 완료.
# 202407010900 데이터 수집 완료.
# 202407011200 데이터 수집 완료.
# 202407011500 데이터 수집 완료.
# 202407011800 데이터 수집 완료.
# 202407012100 데이터 수집 완료.
# 202407020000 데이터 수집 완료.
# 202407020300 데이터 수집 완료.
# 202407020600 데이터 수집 완료.
# 202407020900 데이터 수집 완료.
# 202407021200 데이터 수집 완료.
# 202407021500 데이터 수집 완료.
# 202407021800 데이터 수집 완료.
# 202407022100 데이터 수집 완료.
# 202407030000 데이터 수집 완료.
# 202407030300 데이터 수집 완료.
# 202407030600 데이터 수집 완료.
# 202407030900 데이터 수집 완료.
# 202407031200 데이터 수집 완료.
# 202407031500 데이터 수집 완료.
# 202407031800 데이터 수집 완료.
# 202407032100 데이터 수집 완료.
# 202407040000 데이터 수집 완료.
# 202407040300 데이터 수집 완료.
# 202407040600 데이터 수집 완료.
# 202407040900 데이터 수집 완료.
# 202407041200 데이터 수집 완료.
# 202407041500 데이터 수집 완료.
# 202407041800 데이터 수집 완료.
# 202407042100 데이터 수집 완료.
# 202407050000 데이터 수집 완료.
# 202407050300 데이터 수집 완료.
# 202407050600 데이터 수집 완료.
# 202407050900 데이터 수집 완료.
# 202407051200 데이터 수집 완료.
# 202407051500 데이터 수집 완료.
# 202407051800 데이터 수집 완료.
# 202407052100 데이터 수집 완료.
# 202407060000 데이터 수집 완료.
# 202407060300 데이터 수집 완료.
# 202407060600 데이터 수집 완료.
# 202407060900 데이터 수집 완료.
# 202407061200 데이터 수집 완료.
# 202407061500 데이터 수집 완료.
# 202407061800 데이터 수집 완료.
# 202407062100 데이터 수집 완료.
# 202407070000 데이터 수집 완료.
# 202407070300 데이터 수집 완료.
# 202407070600 데이터 수집 완료.
# 202407070900 데이터 수집 완료.
# 202407071200 데이터 수집 완료.
# 202407071500 데이터 수집 완료.
# 202407071800 데이터 수집 완료.
# 202407072100 데이터 수집 완료.
# 202407080000 데이터 수집 완료.
# 202407080300 데이터 수집 완료.
# 202407080600 데이터 수집 완료.
# 202407080900 데이터 수집 완료.
# 202407081200 데이터 수집 완료.
# 202407081500 데이터 수집 완료.
# 202407081800 데이터 수집 완료.
# 202407082100 데이터 수집 완료.
# 202407090000 데이터 수집 완료.
# 202407090300 데이터 수집 완료.
# 202407090600 데이터 수집 완료.
# 202407090900 데이터 수집 완료.
# 202407091200 데이터 수집 완료.
# 202407091500 데이터 수집 완료.
# 202407091800 데이터 수집 완료.
# 202407092100 데이터 수집 완료.
# 202407100000 데이터 수집 완료.
# 202407100300 데이터 수집 완료.
# 202407100600 데이터 수집 완료.
# 202407100900 데이터 수집 완료.
# 202407101200 데이터 수집 완료.
# 202407101500 데이터 수집 완료.
# 202407101800 데이터 수집 완료.
# 202407102100 데이터 수집 완료.
# 202407110000 데이터 수집 완료.
# 202407110300 데이터 수집 완료.
# 202407110600 데이터 수집 완료.
# 202407110900 데이터 수집 완료.
# 202407111200 데이터 수집 완료.
# 202407111500 데이터 수집 완료.
# 202407111800 데이터 수집 완료.
# 202407112100 데이터 수집 완료.
# 202407120000 데이터 수집 완료.
# 202407120300 데이터 수집 완료.
# 202407120600 데이터 수집 완료.
# 202407120900 데이터 수집 완료.
# 202407121200 데이터 수집 완료.
# 202407121500 데이터 수집 완료.
# 202407121800 데이터 수집 완료.
# 202407122100 데이터 수집 완료.
# 202407130000 데이터 수집 완료.
# 202407130300 데이터 수집 완료.
# 202407130600 데이터 수집 완료.
# 202407130900 데이터 수집 완료.
# 202407131200 데이터 수집 완료.
# 202407131500 데이터 수집 완료.
# 202407131800 데이터 수집 완료.
# 202407132100 데이터 수집 완료.
# 202407140000 데이터 수집 완료.
# 202407140300 데이터 수집 완료.
# 202407140600 데이터 수집 완료.
# 202407140900 데이터 수집 완료.
# 202407141200 데이터 수집 완료.
# 202407141500 데이터 수집 완료.
# 202407141800 데이터 수집 완료.
# 202407142100 데이터 수집 완료.
# 202407150000 데이터 수집 완료.
# 202407150300 데이터 수집 완료.
# 202407150600 데이터 수집 완료.
# 202407150900 데이터 수집 완료.
# 202407151200 데이터 수집 완료.
# 202407151500 데이터 수집 완료.
# 202407151800 데이터 수집 완료.
# 202407152100 데이터 수집 완료.
# 202407160000 데이터 수집 완료.
# 202407160300 데이터 수집 완료.
# 202407160600 데이터 수집 완료.
# 202407160900 데이터 수집 완료.
# 202407161200 데이터 수집 완료.
# 202407161500 데이터 수집 완료.
# 202407161800 데이터 수집 완료.
# 202407162100 데이터 수집 완료.
# 202407170000 데이터 수집 완료.
# 202407170300 데이터 수집 완료.
# 202407170600 데이터 수집 완료.
# 202407170900 데이터 수집 완료.
# 202407171200 데이터 수집 완료.
# 202407171500 데이터 수집 완료.
# 202407171800 데이터 수집 완료.
# 202407172100 데이터 수집 완료.
# 202407180000 데이터 수집 완료.
# 202407180300 데이터 수집 완료.
# 202407180600 데이터 수집 완료.
# 202407180900 데이터 수집 완료.
# 202407181200 데이터 수집 완료.
# 202407181500 데이터 수집 완료.
# 202407181800 데이터 수집 완료.
# 202407182100 데이터 수집 완료.
# 202407190000 데이터 수집 완료.
# 202407190300 데이터 수집 완료.
# 202407190600 데이터 수집 완료.
# 202407190900 데이터 수집 완료.
# 202407191200 데이터 수집 완료.
# 202407191500 데이터 수집 완료.
# 202407191800 데이터 수집 완료.
# 202407192100 데이터 수집 완료.
# 202407200000 데이터 수집 완료.
# 202407200300 데이터 수집 완료.
# 202407200600 데이터 수집 완료.
# 202407200900 데이터 수집 완료.
# 202407201200 데이터 수집 완료.
# 202407201500 데이터 수집 완료.
# 202407201800 데이터 수집 완료.
# 202407202100 데이터 수집 완료.
# 202407210000 데이터 수집 완료.
# 202407210300 데이터 수집 완료.
# 202407210600 데이터 수집 완료.
# 202407210900 데이터 수집 완료.
# 202407211200 데이터 수집 완료.
# 202407211500 데이터 수집 완료.
# 202407211800 데이터 수집 완료.
# 202407212100 데이터 수집 완료.
# 202407220000 데이터 수집 완료.
# 202407220300 데이터 수집 완료.
# 202407220600 데이터 수집 완료.
# 202407220900 데이터 수집 완료.
# 202407221200 데이터 수집 완료.
# 202407221500 데이터 수집 완료.
# 202407221800 데이터 수집 완료.
# 202407222100 데이터 수집 완료.
# 202407230000 데이터 수집 완료.
# 202407230300 데이터 수집 완료.
# 202407230600 데이터 수집 완료.
# 202407230900 데이터 수집 완료.
# 202407231200 데이터 수집 완료.
# 202407231500 데이터 수집 완료.
# 202407231800 데이터 수집 완료.
# 202407232100 데이터 수집 완료.
# 202407240000 데이터 수집 완료.
# 202407240300 데이터 수집 완료.
# 202407240600 데이터 수집 완료.
# 202407240900 데이터 수집 완료.
# 202407241200 데이터 수집 완료.
# 202407241500 데이터 수집 완료.
# 202407241800 데이터 수집 완료.
# 202407242100 데이터 수집 완료.
# 202407250000 데이터 수집 완료.
# 202407250300 데이터 수집 완료.
# 202407250600 데이터 수집 완료.
# 202407250900 데이터 수집 완료.
# 202407251200 데이터 수집 완료.
# 202407251500 데이터 수집 완료.
# 202407251800 데이터 수집 완료.
# 202407252100 데이터 수집 완료.
# 202407260000 데이터 수집 완료.
# 202407260300 데이터 수집 완료.
# 202407260600 데이터 수집 완료.
# 202407260900 데이터 수집 완료.
# 202407261200 데이터 수집 완료.
# 202407261500 데이터 수집 완료.
# 202407261800 데이터 수집 완료.
# 202407262100 데이터 수집 완료.
# 202407270000 데이터 수집 완료.
# 202407270300 데이터 수집 완료.
# 202407270600 데이터 수집 완료.
# 202407270900 데이터 수집 완료.
# 202407271200 데이터 수집 완료.
# 202407271500 데이터 수집 완료.
# 202407271800 데이터 수집 완료.
# 202407272100 데이터 수집 완료.
# 202407280000 데이터 수집 완료.
# 202407280300 데이터 수집 완료.
# 202407280600 데이터 수집 완료.
# 202407280900 데이터 수집 완료.
# 202407281200 데이터 수집 완료.
# 202407281500 데이터 수집 완료.
# 202407281800 데이터 수집 완료.
# 202407282100 데이터 수집 완료.
# 202407290000 데이터 수집 완료.
# 202407290300 데이터 수집 완료.
# 202407290600 데이터 수집 완료.
# 202407290900 데이터 수집 완료.
# 202407291200 데이터 수집 완료.
# 202407291500 데이터 수집 완료.
# 202407291800 데이터 수집 완료.
# 202407292100 데이터 수집 완료.
# 202407300000 데이터 수집 완료.
# 202407300300 데이터 수집 완료.
# 202407300600 데이터 수집 완료.
# 202407300900 데이터 수집 완료.
# 202407301200 데이터 수집 완료.
# 202407301500 데이터 수집 완료.
# 202407301800 데이터 수집 완료.
# 202407302100 데이터 수집 완료.
# 202407310000 데이터 수집 완료.
# 202407310300 데이터 수집 완료.
# 202407310600 데이터 수집 완료.
# 202407310900 데이터 수집 완료.
# 202407311200 데이터 수집 완료.
# 202407311500 데이터 수집 완료.
# 202407311800 데이터 수집 완료.
# 202407312100 데이터 수집 완료.
# 202408010000 데이터 수집 완료.
# 202408010300 데이터 수집 완료.
# 202408010600 데이터 수집 완료.
# 202408010900 데이터 수집 완료.
# 202408011200 데이터 수집 완료.
# 202408011500 데이터 수집 완료.
# 202408011800 데이터 수집 완료.
# 202408012100 데이터 수집 완료.
# 202408020000 데이터 수집 완료.
# 202408020300 데이터 수집 완료.
# 202408020600 데이터 수집 완료.
# 202408020900 데이터 수집 완료.
# 202408021200 데이터 수집 완료.
# 202408021500 데이터 수집 완료.
# 202408021800 데이터 수집 완료.
# 202408022100 데이터 수집 완료.
# 202408030000 데이터 수집 완료.
# 202408030300 데이터 수집 완료.
# 202408030600 데이터 수집 완료.
# 202408030900 데이터 수집 완료.
# 202408031200 데이터 수집 완료.
# 202408031500 데이터 수집 완료.
# 202408031800 데이터 수집 완료.
# 202408032100 데이터 수집 완료.
# 202408040000 데이터 수집 완료.
# 202408040300 데이터 수집 완료.
# 202408040600 데이터 수집 완료.
# 202408040900 데이터 수집 완료.
# 202408041200 데이터 수집 완료.
# 202408041500 데이터 수집 완료.
# 202408041800 데이터 수집 완료.
# 202408042100 데이터 수집 완료.
# 202408050000 데이터 수집 완료.
# 202408050300 데이터 수집 완료.
# 202408050600 데이터 수집 완료.
# 202408050900 데이터 수집 완료.
# 202408051200 데이터 수집 완료.
# 202408051500 데이터 수집 완료.
# 202408051800 데이터 수집 완료.
# 202408052100 데이터 수집 완료.
# 202408060000 데이터 수집 완료.
# 202408060300 데이터 수집 완료.
# 202408060600 데이터 수집 완료.
# 202408060900 데이터 수집 완료.
# 202408061200 데이터 수집 완료.
# 202408061500 데이터 수집 완료.
# 202408061800 데이터 수집 완료.
# 202408062100 데이터 수집 완료.
# 202408070000 데이터 수집 완료.
# 202408070300 데이터 수집 완료.
# 202408070600 데이터 수집 완료.
# 202408070900 데이터 수집 완료.
# 202408071200 데이터 수집 완료.
# 202408071500 데이터 수집 완료.
# 202408071800 데이터 수집 완료.
# 202408072100 데이터 수집 완료.
# 202408080000 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202408080300 데이터 수집 완료.
# 202408080600 데이터 수집 완료.
# 202408080900 데이터 수집 완료.
# 202408081200 데이터 수집 완료.
# 202408081500 데이터 수집 완료.
# 202408081800 데이터 수집 완료.
# 202408082100 데이터 수집 완료.
# 202408090000 데이터 수집 완료.
# 202408090300 데이터 수집 완료.
# 202408090600 데이터 수집 완료.
# 202408090900 데이터 수집 완료.
# 202408091200 데이터 수집 완료.
# 202408091500 데이터 수집 완료.
# 202408091800 데이터 수집 완료.
# 202408092100 데이터 수집 완료.
# 202408100000 데이터 수집 완료.
# 202408100300 데이터 수집 완료.
# 202408100600 데이터 수집 완료.
# 202408100900 데이터 수집 완료.
# 202408101200 데이터 수집 완료.
# 202408101500 데이터 수집 완료.
# 202408101800 데이터 수집 완료.
# 202408102100 데이터 수집 완료.
# 202408110000 데이터 수집 완료.
# 202408110300 데이터 수집 완료.
# 202408110600 데이터 수집 완료.
# 202408110900 데이터 수집 완료.
# 202408111200 데이터 수집 완료.
# 202408111500 데이터 수집 완료.
# 202408111800 데이터 수집 완료.
# 202408112100 데이터 수집 완료.
# 202408120000 데이터 수집 완료.
# 202408120300 데이터 수집 완료.
# 202408120600 데이터 수집 완료.
# 202408120900 데이터 수집 완료.
# 202408121200 데이터 수집 완료.
# 202408121500 데이터 수집 완료.
# 202408121800 데이터 수집 완료.
# 202408122100 데이터 수집 완료.
# 202408130000 데이터 수집 완료.
# 202408130300 데이터 수집 완료.
# 202408130600 데이터 수집 완료.
# 202408130900 데이터 수집 완료.
# 202408131200 데이터 수집 완료.
# 202408131500 데이터 수집 완료.
# 202408131800 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202408132100 데이터 수집 완료.
# 202408140000 데이터 수집 완료.
# 202408140300 데이터 수집 완료.
# 202408140600 데이터 수집 완료.
# 202408140900 데이터 수집 완료.
# 202408141200 데이터 수집 완료.
# 202408141500 데이터 수집 완료.
# 202408141800 데이터 수집 완료.
# 202408142100 데이터 수집 완료.
# 202408150000 데이터 수집 완료.
# 202408150300 데이터 수집 완료.
# 202408150600 데이터 수집 완료.
# 202408150900 데이터 수집 완료.
# 202408151200 데이터 수집 완료.
# 202408151500 데이터 수집 완료.
# 202408151800 데이터 수집 완료.
# 202408152100 데이터 수집 완료.
# 202408160000 데이터 수집 완료.
# 202408160300 데이터 수집 완료.
# 202408160600 데이터 수집 완료.
# 202408160900 데이터 수집 완료.
# 202408161200 데이터 수집 완료.
# 202408161500 데이터 수집 완료.
# 202408161800 데이터 수집 완료.
# 202408162100 데이터 수집 완료.
# 202408170000 데이터 수집 완료.
# 202408170300 데이터 수집 완료.
# 202408170600 데이터 수집 완료.
# 202408170900 데이터 수집 완료.
# 202408171200 데이터 수집 완료.
# 202408171500 데이터 수집 완료.
# 202408171800 데이터 수집 완료.
# 202408172100 데이터 수집 완료.
# 202408180000 데이터 수집 완료.
# 202408180300 데이터 수집 완료.
# 202408180600 데이터 수집 완료.
# 202408180900 데이터 수집 완료.
# 202408181200 데이터 수집 완료.
# 202408181500 데이터 수집 완료.
# 202408181800 데이터 수집 완료.
# 202408182100 데이터 수집 완료.
# 202408190000 데이터 수집 완료.
# 202408190300 데이터 수집 완료.
# 202408190600 데이터 수집 완료.
# 202408190900 데이터 수집 완료.
# 202408191200 데이터 수집 완료.
# 202408191500 데이터 수집 완료.
# 202408191800 데이터 수집 완료.
# 202408192100 데이터 수집 완료.
# 202408200000 데이터 수집 완료.
# 202408200300 데이터 수집 완료.
# 202408200600 데이터 수집 완료.
# 202408200900 데이터 수집 완료.
# 202408201200 데이터 수집 완료.
# 202408201500 데이터 수집 완료.
# 202408201800 데이터 수집 완료.
# 202408202100 데이터 수집 완료.
# 202408210000 데이터 수집 완료.
# 202408210300 데이터 수집 완료.
# 202408210600 데이터 수집 완료.
# 202408210900 데이터 수집 완료.
# 202408211200 데이터 수집 완료.
# 202408211500 데이터 수집 완료.
# 202408211800 데이터 수집 완료.
# 202408212100 데이터 수집 완료.
# 202408220000 데이터 수집 완료.
# 202408220300 데이터 수집 완료.
# 202408220600 데이터 수집 완료.
# 202408220900 데이터 수집 완료.
# 202408221200 데이터 수집 완료.
# 202408221500 데이터 수집 완료.
# 202408221800 데이터 수집 완료.
# 202408222100 데이터 수집 완료.
# 202408230000 데이터 수집 완료.
# 202408230300 데이터 수집 완료.
# 202408230600 데이터 수집 완료.
# 202408230900 데이터 수집 완료.
# 202408231200 데이터 수집 완료.
# 202408231500 데이터 수집 완료.
# 202408231800 데이터 수집 완료.
# 202408232100 데이터 수집 완료.
# 202408240000 데이터 수집 완료.
# 202408240300 데이터 수집 완료.
# 202408240600 데이터 수집 완료.
# 202408240900 데이터 수집 완료.
# 202408241200 데이터 수집 완료.
# 202408241500 데이터 수집 완료.
# 202408241800 데이터 수집 완료.
# 202408242100 데이터 수집 완료.
# 202408250000 데이터 수집 완료.
# 202408250300 데이터 수집 완료.
# 202408250600 데이터 수집 완료.
# 202408250900 데이터 수집 완료.
# 202408251200 데이터 수집 완료.
# 202408251500 데이터 수집 완료.
# 202408251800 데이터 수집 완료.
# 202408252100 데이터 수집 완료.
# 202408260000 데이터 수집 완료.
# 202408260300 데이터 수집 완료.
# 202408260600 데이터 수집 완료.
# 202408260900 데이터 수집 완료.
# 202408261200 데이터 수집 완료.
# 202408261500 데이터 수집 완료.
# 202408261800 데이터 수집 완료.
# 202408262100 데이터 수집 완료.
# 202408270000 데이터 수집 완료.
# 202408270300 데이터 수집 완료.
# 202408270600 데이터 수집 완료.
# 202408270900 데이터 수집 완료.
# 202408271200 데이터 수집 완료.
# 202408271500 데이터 수집 완료.
# 202408271800 데이터 수집 완료.
# 202408272100 데이터 수집 완료.
# 202408280000 데이터 수집 완료.
# 202408280300 데이터 수집 완료.
# 202408280600 데이터 수집 완료.
# 202408280900 데이터 수집 완료.
# 202408281200 데이터 수집 완료.
# 202408281500 데이터 수집 완료.
# 202408281800 데이터 수집 완료.
# 202408282100 데이터 수집 완료.
# 202408290000 데이터 수집 완료.
# 202408290300 데이터 수집 완료.
# 202408290600 데이터 수집 완료.
# 202408290900 데이터 수집 완료.
# 202408291200 데이터 수집 완료.
# ...
# 202410170600 데이터 수집 완료.
# 202410170900 데이터 수집 완료.
# 202410171200 데이터 수집 완료.
# 202410171500 데이터 수집 완료.
# 202410171800 데이터 수집 완료.
# 202410172100 데이터 수집 완료.
# 202410180000 데이터 수집 완료.
# 202410180300 데이터 수집 완료.
# 202410180600 데이터 수집 완료.
# 202410180900 데이터 수집 완료.
# 202410181200 데이터 수집 완료.
# 202410181500 데이터 수집 완료.
# 202410181800 데이터 수집 완료.
# 202410182100 데이터 수집 완료.
# 202410190000 데이터 수집 완료.
# 202410190300 데이터 수집 완료.
# 202410190600 데이터 수집 완료.
# 202410190900 데이터 수집 완료.
# 202410191200 데이터 수집 완료.
# 202410191500 데이터 수집 완료.
# 202410191800 데이터 수집 완료.
# 202410192100 데이터 수집 완료.
# 202410200000 데이터 수집 완료.
# 202410200300 데이터 수집 완료.
# 202410200600 데이터 수집 완료.
# 202410200900 데이터 수집 완료.
# 202410201200 데이터 수집 완료.
# 202410201500 데이터 수집 완료.
# 202410201800 데이터 수집 완료.
# 202410202100 데이터 수집 완료.
# 202410210000 데이터 수집 완료.
# 202410210300 데이터 수집 완료.
# 202410210600 데이터 수집 완료.
# 202410210900 데이터 수집 완료.
# 202410211200 데이터 수집 완료.
# 202410211500 데이터 수집 완료.
# 202410211800 데이터 수집 완료.
# 202410212100 데이터 수집 완료.
# 202410220000 데이터 수집 완료.
# 202410220300 데이터 수집 완료.
# 202410220600 데이터 수집 완료.
# 202410220900 데이터 수집 완료.
# 202410221200 데이터 수집 완료.
# 202410221500 데이터 수집 완료.
# 202410221800 데이터 수집 완료.
# 202410222100 데이터 수집 완료.
# 202410230000 데이터 수집 완료.
# 202410230300 데이터 수집 완료.
# 202410230600 데이터 수집 완료.
# 202410230900 데이터 수집 완료.
# 202410231200 데이터 수집 완료.
# 202410231500 데이터 수집 완료.
# 202410231800 데이터 수집 완료.
# 202410232100 데이터 수집 완료.
# 202410240000 데이터 수집 완료.
# 202410240300 데이터 수집 완료.
# 202410240600 데이터 수집 완료.
# 202410240900 데이터 수집 완료.
# 202410241200 데이터 수집 완료.
# 202410241500 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202410241800 데이터 수집 완료.
# 202410242100 데이터 수집 완료.
# 202410250000 데이터 수집 완료.
# 202410250300 데이터 수집 완료.
# 202410250600 데이터 수집 완료.
# 202410250900 데이터 수집 완료.
# 202410251200 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202410251500 데이터 수집 완료.
# 202410251800 데이터 수집 완료.
# 202410252100 데이터 수집 완료.
# 202410260000 데이터 수집 완료.
# 202410260300 데이터 수집 완료.
# 202410260600 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202410260900 데이터 수집 완료.
# 202410261200 데이터 수집 완료.
# 202410261500 데이터 수집 완료.
# 202410261800 데이터 수집 완료.
# 202410262100 데이터 수집 완료.
# 202410270000 데이터 수집 완료.
# 202410270300 데이터 수집 완료.
# 202410270600 데이터 수집 완료.
# 202410270900 데이터 수집 완료.
# 202410271200 데이터 수집 완료.
# 202410271500 데이터 수집 완료.
# 202410271800 데이터 수집 완료.
# 202410272100 데이터 수집 완료.
# 202410280000 데이터 수집 완료.
# 202410280300 데이터 수집 완료.
# 202410280600 데이터 수집 완료.
# 202410280900 데이터 수집 완료.
# 202410281200 데이터 수집 완료.
# 202410281500 데이터 수집 완료.
# 202410281800 데이터 수집 완료.
# 202410282100 데이터 수집 완료.
# 202410290000 데이터 수집 완료.
# 202410290300 데이터 수집 완료.
# 202410290600 데이터 수집 완료.
# 202410290900 데이터 수집 완료.
# 202410291200 데이터 수집 완료.
# 202410291500 데이터 수집 완료.
# 202410291800 데이터 수집 완료.
# 202410292100 데이터 수집 완료.
# 202410300000 데이터 수집 완료.
# 202410300300 데이터 수집 완료.
# 202410300600 데이터 수집 완료.
# 202410300900 데이터 수집 완료.
# 202410301200 데이터 수집 완료.
# 202410301500 데이터 수집 완료.
# 202410301800 데이터 수집 완료.
# 202410302100 데이터 수집 완료.
# 202410310000 데이터 수집 완료.
# 202410310300 데이터 수집 완료.
# 202410310600 데이터 수집 완료.
# 202410310900 데이터 수집 완료.
# 202410311200 데이터 수집 완료.
# 202410311500 데이터 수집 완료.
# 202410311800 데이터 수집 완료.
# 202410312100 데이터 수집 완료.
# 202411010000 데이터 수집 완료.
# 202411010300 데이터 수집 완료.
# 202411010600 데이터 수집 완료.
# 202411010900 데이터 수집 완료.
# 202411011200 데이터 수집 완료.
# 202411011500 데이터 수집 완료.
# 202411011800 데이터 수집 완료.
# 202411012100 데이터 수집 완료.
# 202411020000 데이터 수집 완료.
# 202411020300 데이터 수집 완료.
# 202411020600 데이터 수집 완료.
# 202411020900 데이터 수집 완료.
# 202411021200 데이터 수집 완료.
# 202411021500 데이터 수집 완료.
# 202411021800 데이터 수집 완료.
# 202411022100 데이터 수집 완료.
# 202411030000 데이터 수집 완료.
# 202411030300 데이터 수집 완료.
# 202411030600 데이터 수집 완료.
# 202411030900 데이터 수집 완료.
# 202411031200 데이터 수집 완료.
# 202411031500 데이터 수집 완료.
# 202411031800 데이터 수집 완료.
# 202411032100 데이터 수집 완료.
# 202411040000 데이터 수집 완료.
# 202411040300 데이터 수집 완료.
# 202411040600 데이터 수집 완료.
# 202411040900 데이터 수집 완료.
# 202411041200 데이터 수집 완료.
# 202411041500 데이터 수집 완료.
# 202411041800 데이터 수집 완료.
# 202411042100 데이터 수집 완료.
# 202411050000 데이터 수집 완료.
# 202411050300 데이터 수집 완료.
# 202411050600 데이터 수집 완료.
# 202411050900 데이터 수집 완료.
# 202411051200 데이터 수집 완료.
# 202411051500 데이터 수집 완료.
# 202411051800 데이터 수집 완료.
# 202411052100 데이터 수집 완료.
# 202411060000 데이터 수집 완료.
# 202411060300 데이터 수집 완료.
# 202411060600 데이터 수집 완료.
# 202411060900 데이터 수집 완료.
# 202411061200 데이터 수집 완료.
# 202411061500 데이터 수집 완료.
# 202411061800 데이터 수집 완료.
# 202411062100 데이터 수집 완료.
# 202411070000 데이터 수집 완료.
# 202411070300 데이터 수집 완료.
# 202411070600 데이터 수집 완료.
# 202411070900 데이터 수집 완료.
# 202411071200 데이터 수집 완료.
# 202411071500 데이터 수집 완료.
# 202411071800 데이터 수집 완료.
# 202411072100 데이터 수집 완료.
# 202411080000 데이터 수집 완료.
# 202411080300 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202411080600 데이터 수집 완료.
# 202411080900 데이터 수집 완료.
# 202411081200 데이터 수집 완료.
# 202411081500 데이터 수집 완료.
# 202411081800 데이터 수집 완료.
# 202411082100 데이터 수집 완료.
# 202411090000 데이터 수집 완료.
# 202411090300 데이터 수집 완료.
# 202411090600 데이터 수집 완료.
# 202411090900 데이터 수집 완료.
# 202411091200 데이터 수집 완료.
# 202411091500 데이터 수집 완료.
# 202411091800 데이터 수집 완료.
# 202411092100 데이터 수집 완료.
# 202411100000 데이터 수집 완료.
# 202411100300 데이터 수집 완료.
# 202411100600 데이터 수집 완료.
# 202411100900 데이터 수집 완료.
# 202411101200 데이터 수집 완료.
# 202411101500 데이터 수집 완료.
# 202411101800 데이터 수집 완료.
# 202411102100 데이터 수집 완료.
# 202411110000 데이터 수집 완료.
# 202411110300 데이터 수집 완료.
# 202411110600 데이터 수집 완료.
# 202411110900 데이터 수집 완료.
# 202411111200 데이터 수집 완료.
# 202411111500 데이터 수집 완료.
# 202411111800 데이터 수집 완료.
# 202411112100 데이터 수집 완료.
# 202411120000 데이터 수집 완료.
# 202411120300 데이터 수집 완료.
# 202411120600 데이터 수집 완료.
# 202411120900 데이터 수집 완료.
# 202411121200 데이터 수집 완료.
# 202411121500 데이터 수집 완료.
# 202411121800 데이터 수집 완료.
# 202411122100 데이터 수집 완료.
# 202411130000 데이터 수집 완료.
# 202411130300 데이터 수집 완료.
# 202411130600 데이터 수집 완료.
# 202411130900 데이터 수집 완료.
# 202411131200 데이터 수집 완료.
# 202411131500 데이터 수집 완료.
# 202411131800 데이터 수집 완료.
# 202411132100 데이터 수집 완료.
# 202411140000 데이터 수집 완료.
# 202411140300 데이터 수집 완료.
# 202411140600 데이터 수집 완료.
# 202411140900 데이터 수집 완료.
# 202411141200 데이터 수집 완료.
# 202411141500 데이터 수집 완료.
# 202411141800 데이터 수집 완료.
# 202411142100 데이터 수집 완료.
# 202411150000 데이터 수집 완료.
# 202411150300 데이터 수집 완료.
# 202411150600 데이터 수집 완료.
# 202411150900 데이터 수집 완료.
# 202411151200 데이터 수집 완료.
# 202411151500 데이터 수집 완료.
# 202411151800 데이터 수집 완료.
# 202411152100 데이터 수집 완료.
# 202411160000 데이터 수집 완료.
# 202411160300 데이터 수집 완료.
# 202411160600 데이터 수집 완료.
# 202411160900 데이터 수집 완료.
# 202411161200 데이터 수집 완료.
# 202411161500 데이터 수집 완료.
# 202411161800 데이터 수집 완료.
# 202411162100 데이터 수집 완료.
# 202411170000 데이터 수집 완료.
# 202411170300 데이터 수집 완료.
# 202411170600 데이터 수집 완료.
# 202411170900 데이터 수집 완료.
# 202411171200 데이터 수집 완료.
# 202411171500 데이터 수집 완료.
# 202411171800 데이터 수집 완료.
# 202411172100 데이터 수집 완료.
# 202411180000 데이터 수집 완료.
# 202411180300 데이터 수집 완료.
# 202411180600 데이터 수집 완료.
# 202411180900 데이터 수집 완료.
# 202411181200 데이터 수집 완료.
# 202411181500 데이터 수집 완료.
# 202411181800 데이터 수집 완료.
# 202411182100 데이터 수집 완료.
# 202411190000 데이터 수집 완료.
# 202411190300 데이터 수집 완료.
# 202411190600 데이터 수집 완료.
# 202411190900 데이터 수집 완료.
# 202411191200 데이터 수집 완료.
# 202411191500 데이터 수집 완료.
# 202411191800 데이터 수집 완료.
# 202411192100 데이터 수집 완료.
# 202411200000 데이터 수집 완료.
# 202411200300 데이터 수집 완료.
# 202411200600 데이터 수집 완료.
# 202411200900 데이터 수집 완료.
# 202411201200 데이터 수집 완료.
# 202411201500 데이터 수집 완료.
# 202411201800 데이터 수집 완료.
# 202411202100 데이터 수집 완료.
# 202411210000 데이터 수집 완료.
# 202411210300 데이터 수집 완료.
# 202411210600 데이터 수집 완료.
# 202411210900 데이터 수집 완료.
# 202411211200 데이터 수집 완료.
# 202411211500 데이터 수집 완료.
# 202411211800 데이터 수집 완료.
# 202411212100 데이터 수집 완료.
# 202411220000 데이터 수집 완료.
# 202411220300 데이터 수집 완료.
# 202411220600 데이터 수집 완료.
# 202411220900 데이터 수집 완료.
# 202411221200 데이터 수집 완료.
# 202411221500 데이터 수집 완료.
# 202411221800 데이터 수집 완료.
# 202411222100 데이터 수집 완료.
# 202411230000 데이터 수집 완료.
# 202411230300 데이터 수집 완료.
# 202411230600 데이터 수집 완료.
# 202411230900 데이터 수집 완료.
# 202411231200 데이터 수집 완료.
# 202411231500 데이터 수집 완료.
# 202411231800 데이터 수집 완료.
# 202411232100 데이터 수집 완료.
# 202411240000 데이터 수집 완료.
# 202411240300 데이터 수집 완료.
# 202411240600 데이터 수집 완료.
# 202411240900 데이터 수집 완료.
# 202411241200 데이터 수집 완료.
# 202411241500 데이터 수집 완료.
# 202411241800 데이터 수집 완료.
# 202411242100 데이터 수집 완료.
# 202411250000 데이터 수집 완료.
# 202411250300 데이터 수집 완료.
# 202411250600 데이터 수집 완료.
# 202411250900 데이터 수집 완료.
# 202411251200 데이터 수집 완료.
# 202411251500 데이터 수집 완료.
# 202411251800 데이터 수집 완료.
# 202411252100 데이터 수집 완료.
# 202411260000 데이터 수집 완료.
# 202411260300 데이터 수집 완료.
# 202411260600 데이터 수집 완료.
# 202411260900 데이터 수집 완료.
# 202411261200 데이터 수집 완료.
# 202411261500 데이터 수집 완료.
# 202411261800 데이터 수집 완료.
# 202411262100 데이터 수집 완료.
# 202411270000 데이터 수집 완료.
# 202411270300 데이터 수집 완료.
# 202411270600 데이터 수집 완료.
# 202411270900 데이터 수집 완료.
# 202411271200 데이터 수집 완료.
# 202411271500 데이터 수집 완료.
# 202411271800 데이터 수집 완료.
# 202411272100 데이터 수집 완료.
# 202411280000 데이터 수집 완료.
# 202411280300 데이터 수집 완료.
# 202411280600 데이터 수집 완료.
# 202411280900 데이터 수집 완료.
# 202411281200 데이터 수집 완료.
# 202411281500 데이터 수집 완료.
# 202411281800 데이터 수집 완료.
# 202411282100 데이터 수집 완료.
# 202411290000 데이터 수집 완료.
# 202411290300 데이터 수집 완료.
# 202411290600 데이터 수집 완료.
# 202411290900 데이터 수집 완료.
# 202411291200 데이터 수집 완료.
# 202411291500 데이터 수집 완료.
# 202411291800 데이터 수집 완료.
# 202411292100 데이터 수집 완료.
# 202411300000 데이터 수집 완료.
# 202411300300 데이터 수집 완료.
# 202411300600 데이터 수집 완료.
# 202411300900 데이터 수집 완료.
# 202411301200 데이터 수집 완료.
# 202411301500 데이터 수집 완료.
# 202411301800 데이터 수집 완료.
# 202411302100 데이터 수집 완료.
# 202412010000 데이터 수집 완료.
# 202412010300 데이터 수집 완료.
# 202412010600 데이터 수집 완료.
# 202412010900 데이터 수집 완료.
# 202412011200 데이터 수집 완료.
# 202412011500 데이터 수집 완료.
# 202412011800 데이터 수집 완료.
# 202412012100 데이터 수집 완료.
# 202412020000 데이터 수집 완료.
# 202412020300 데이터 수집 완료.
# 202412020600 데이터 수집 완료.
# 202412020900 데이터 수집 완료.
# 202412021200 데이터 수집 완료.
# 202412021500 데이터 수집 완료.
# 202412021800 데이터 수집 완료.
# 202412022100 데이터 수집 완료.
# 202412030000 데이터 수집 완료.
# 202412030300 데이터 수집 완료.
# 202412030600 데이터 수집 완료.
# 202412030900 데이터 수집 완료.
# 202412031200 데이터 수집 완료.
# 202412031500 데이터 수집 완료.
# 202412031800 데이터 수집 완료.
# 202412032100 데이터 수집 완료.
# 202412040000 데이터 수집 완료.
# 202412040300 데이터 수집 완료.
# 202412040600 데이터 수집 완료.
# 202412040900 데이터 수집 완료.
# 202412041200 데이터 수집 완료.
# 202412041500 데이터 수집 완료.
# 202412041800 데이터 수집 완료.
# 202412042100 데이터 수집 완료.
# 202412050000 데이터 수집 완료.
# 202412050300 데이터 수집 완료.
# 202412050600 데이터 수집 완료.
# 202412050900 데이터 수집 완료.
# 202412051200 데이터 수집 완료.
# 202412051500 데이터 수집 완료.
# 202412051800 데이터 수집 완료.
# 202412052100 데이터 수집 완료.
# 202412060000 데이터 수집 완료.
# 202412060300 데이터 수집 완료.
# 202412060600 데이터 수집 완료.
# 202412060900 데이터 수집 완료.
# 202412061200 데이터 수집 완료.
# 202412061500 데이터 수집 완료.
# 202412061800 데이터 수집 완료.
# 202412062100 데이터 수집 완료.
# 202412070000 데이터 수집 완료.
# 202412070300 데이터 수집 완료.
# 202412070600 데이터 수집 완료.
# 202412070900 데이터 수집 완료.
# 202412071200 데이터 수집 완료.
# 202412071500 데이터 수집 완료.
# 202412071800 데이터 수집 완료.
# 202412072100 데이터 수집 완료.
# 202412080000 데이터 수집 완료.
# 202412080300 데이터 수집 완료.
# 202412080600 데이터 수집 완료.
# 202412080900 데이터 수집 완료.
# 202412081200 데이터 수집 완료.
# 202412081500 데이터 수집 완료.
# 202412081800 데이터 수집 완료.
# 202412082100 데이터 수집 완료.
# 202412090000 데이터 수집 완료.
# 202412090300 데이터 수집 완료.
# 202412090600 데이터 수집 완료.
# 202412090900 데이터 수집 완료.
# 202412091200 데이터 수집 완료.
# 202412091500 데이터 수집 완료.
# 202412091800 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202412092100 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202412100000 데이터 요청 실패: Expecting value: line 1 column 1 (char 0)
# 202412100300 데이터 요청 실패: Expecting value: line 1 column 1 (char 0)
# 202412100600 데이터 요청 실패: Expecting value: line 1 column 1 (char 0)
# 202412100900 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202412101200 데이터 요청 실패: Expecting value: line 1 column 1 (char 0)
# 202412101500 데이터 요청 실패: Expecting value: line 1 column 1 (char 0)
# 202412101800 데이터 요청 실패: Expecting value: line 1 column 1 (char 0)
# 202412102100 데이터 요청 실패: Expecting value: line 1 column 1 (char 0)
# 202412110000 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202412110300 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202412110600 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202412110900 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202412111200 데이터 수집 완료.
# 202412111500 데이터 수집 완료.
# 202412111800 데이터 수집 완료.
# 202412112100 데이터 수집 완료.
# 202412120000 데이터 수집 완료.
# 202412120300 데이터 수집 완료.
# 202412120600 데이터 수집 완료.
# 202412120900 데이터 수집 완료.
# 202412121200 데이터 수집 완료.
# 202412121500 데이터 수집 완료.
# 202412121800 데이터 수집 완료.
# 202412122100 데이터 수집 완료.
# 202412130000 데이터 수집 완료.
# 202412130300 데이터 수집 완료.
# 202412130600 데이터 수집 완료.
# 202412130900 데이터 수집 완료.
# 202412131200 데이터 수집 완료.
# 202412131500 데이터 수집 완료.
# 202412131800 데이터 수집 완료.
# 202412132100 데이터 수집 완료.
# 202412140000 데이터 수집 완료.
# 202412140300 데이터 수집 완료.
# 202412140600 데이터 수집 완료.
# 202412140900 데이터 수집 완료.
# 202412141200 데이터 수집 완료.
# 202412141500 데이터 수집 완료.
# 202412141800 데이터 수집 완료.
# 202412142100 데이터 수집 완료.
# 202412150000 데이터 수집 완료.
# 202412150300 데이터 수집 완료.
# 202412150600 데이터 수집 완료.
# 202412150900 데이터 수집 완료.
# 202412151200 데이터 수집 완료.
# 202412151500 데이터 수집 완료.
# 202412151800 데이터 수집 완료.
# 202412152100 데이터 수집 완료.
# 202412160000 데이터 수집 완료.
# 202412160300 데이터 수집 완료.
# 202412160600 데이터 수집 완료.
# 202412160900 데이터 수집 완료.
# 202412161200 데이터 수집 완료.
# 202412161500 데이터 수집 완료.
# 202412161800 데이터 수집 완료.
# 202412162100 데이터 수집 완료.
# 202412170000 데이터 수집 완료.
# 202412170300 데이터 수집 완료.
# 202412170600 데이터 수집 완료.
# 202412170900 데이터 수집 완료.
# 202412171200 데이터 수집 완료.
# 202412171500 데이터 수집 완료.
# 202412171800 데이터 수집 완료.
# 202412172100 데이터 수집 완료.
# 202412180000 데이터 수집 완료.
# 202412180300 데이터 수집 완료.
# 202412180600 데이터 수집 완료.
# 202412180900 데이터 수집 완료.
# 202412181200 데이터 수집 완료.
# 202412181500 데이터 수집 완료.
# 202412181800 데이터 수집 완료.
# 202412182100 데이터 수집 완료.
# 202412190000 데이터 수집 완료.
# 202412190300 데이터 수집 완료.
# 202412190600 데이터 수집 완료.
# 202412190900 데이터 수집 완료.
# 202412191200 데이터 수집 완료.
# 202412191500 데이터 수집 완료.
# 202412191800 데이터 수집 완료.
# 202412192100 데이터 수집 완료.
# 202412200000 데이터 수집 완료.
# 202412200300 데이터 수집 완료.
# 202412200600 데이터 수집 완료.
# 202412200900 데이터 수집 완료.
# 202412201200 데이터 수집 완료.
# 202412201500 데이터 수집 완료.
# 202412201800 데이터 수집 완료.
# 202412202100 데이터 수집 완료.
# 202412210000 데이터 수집 완료.
# 202412210300 데이터 수집 완료.
# 202412210600 데이터 수집 완료.
# 202412210900 데이터 수집 완료.
# 202412211200 데이터 수집 완료.
# 202412211500 데이터 수집 완료.
# 202412211800 데이터 수집 완료.
# 202412212100 데이터 수집 완료.
# 202412220000 데이터 수집 완료.
# 202412220300 데이터 수집 완료.
# 202412220600 데이터 수집 완료.
# 202412220900 데이터 수집 완료.
# 202412221200 데이터 수집 완료.
# 202412221500 데이터 수집 완료.
# 202412221800 데이터 수집 완료.
# 202412222100 데이터 수집 완료.
# 202412230000 데이터 수집 완료.
# 202412230300 데이터 수집 완료.
# 202412230600 데이터 수집 완료.
# 202412230900 데이터 수집 완료.
# 202412231200 데이터 수집 완료.
# 202412231500 데이터 수집 완료.
# 202412231800 데이터 수집 완료.
# 202412232100 데이터 수집 완료.
# 202412240000 데이터 수집 완료.
# 202412240300 데이터 수집 완료.
# 202412240600 데이터 수집 완료.
# 202412240900 데이터 수집 완료.
# 202412241200 데이터 수집 완료.
# 202412241500 데이터 수집 완료.
# 202412241800 데이터 수집 완료.
# 202412242100 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202412250000 데이터 수집 완료.
# 202412250300 데이터 수집 완료.
# 202412250600 데이터 수집 완료.
# 202412250900 데이터 수집 완료.
# 202412251200 데이터 수집 완료.
# 202412251500 데이터 수집 완료.
# 202412251800 데이터 수집 완료.
# 202412252100 데이터 수집 완료.
# 202412260000 데이터 수집 완료.
# 202412260300 데이터 수집 완료.
# 202412260600 데이터 수집 완료.
# 202412260900 데이터 수집 완료.
# 202412261200 데이터 수집 완료.
# 202412261500 데이터 수집 완료.
# 202412261800 데이터 수집 완료.
# 202412262100 데이터 수집 완료.
# 202412270000 데이터 수집 완료.
# 202412270300 데이터 수집 완료.
# 202412270600 데이터 수집 완료.
# 202412270900 데이터 수집 완료.
# 202412271200 데이터 수집 완료.
# 202412271500 데이터 수집 완료.
# 202412271800 데이터 수집 완료.
# 202412272100 데이터 수집 완료.
# 202412280000 데이터 수집 완료.
# 202412280300 데이터 수집 완료.
# 202412280600 데이터 수집 완료.
# 202412280900 데이터 수집 완료.
# 202412281200 데이터 수집 완료.
# 202412281500 데이터 수집 완료.
# 202412281800 데이터 수집 완료.
# 202412282100 데이터 수집 완료.
# 202412290000 데이터 수집 완료.
# 202412290300 데이터 수집 완료.
# 202412290600 데이터 수집 완료.
# 202412290900 데이터 수집 완료.
# 202412291200 데이터 수집 완료.
# 202412291500 데이터 수집 완료.
# 202412291800 데이터 수집 완료.
# 202412292100 데이터 수집 완료.
# 202412300000 데이터 수집 완료.
# 202412300300 데이터 수집 완료.
# 202412300600 데이터 수집 완료.
# 202412300900 데이터 수집 완료.
# 202412301200 데이터 수집 완료.
# 202412301500 데이터 수집 완료.
# 202412301800 데이터 수집 완료.
# 202412302100 데이터 수집 완료.
# 202412310000 데이터 수집 완료.
# 202412310300 데이터 수집 완료.
# 202412310600 데이터 수집 완료.
# 202412310900 데이터 수집 완료.
# 202412311200 데이터 수집 완료.
# 202412311500 데이터 수집 완료.
# 202412311800 데이터 요청 실패: HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)
# 202412312100 데이터 수집 완료.
# CSV 파일 저장 완료: weather_data.csv

# %%
import requests
import time
import pandas as pd
from datetime import datetime, timedelta
import logging

# API 기본 설정
API_URL = 'http://apis.data.go.kr/1360000/AirInfoService/getAirInfo'
PARAMS = {
    'numOfRows': '100',
    'pageNo': '1',
    'dataType': 'JSON',
    'icaoCode': 'RKSI'  # 인천공항
}
# API 인증키 추가 필요

# 시작 날짜 및 종료 날짜 설정
START_DATE = datetime(2024, 1, 1, 0, 0)
END_DATE = datetime(2024, 12, 31, 23, 0)

# 3시간 간격으로 시간 리스트 생성
def generate_time_list(start, end):
    time_list = []
    current_time = start
    while current_time <= end:
        time_list.append(current_time.strftime('%Y%m%d%H%M'))
        current_time += timedelta(hours=3)
    return time_list

time_points = generate_time_list(START_DATE, END_DATE)

# 이미 존재하는 데이터 파일 확인
def load_existing_data():
    try:
        # CSV 파일에서 데이터 읽어오기
        df = pd.read_csv('weather_data.csv', encoding='utf-8-sig')
        # 'timestamp' 컬럼만 리스트로 반환하고, 중복을 피하기 위해 set으로 반환
        existing_timestamps = set(df['timestamp'].astype(str).tolist())  
        return existing_timestamps
    except FileNotFoundError:
        return set()  # 파일이 없으면 빈 set 반환

# API 호출 실행
REQUEST_LIMIT = 10000  # 하루 요청 제한
requests_today = 0

# 데이터 저장 리스트
data_list = []

# 로그 설정
logging.basicConfig(filename='data_request_errors.log', level=logging.ERROR)

def fetch_weather_data(timestamp):
    global requests_today
    if requests_today >= REQUEST_LIMIT:
        print("일일 트래픽 제한 도달. 종료합니다.")
        return False
    
    PARAMS['fctm'] = timestamp
    retry_count = 3  # 실패 시 재시도 횟수
    for _ in range(retry_count):
        try:
            response = requests.get(API_URL, params=PARAMS, timeout=15)  # 타임아웃 시간 증가
            response.raise_for_status()
            json_data = response.json()
            
            if not json_data or not json_data.get('response', {}).get('body', {}).get('items', {}).get('item', []):
                raise ValueError("빈 응답 또는 잘못된 응답 형식")
            
            # JSON에서 필요한 데이터 추출
            for item in json_data.get('response', {}).get('body', {}).get('items', {}).get('item', []):
                data_list.append({
                    'timestamp': item.get('tmFc', 'N/A'),
                    'airport_name': bytes(item.get('airportName', ''), 'utf-8').decode('utf-8', 'ignore'),
                    'wind_direction': item.get('wd', 'N/A'),
                    'wind_speed': item.get('ws', 'N/A'),
                    'temperature': item.get('ta', 'N/A'),
                    'pressure': item.get('qnh', 'N/A')
                })
            
            print(f"{timestamp} 데이터 수집 완료.")
            requests_today += 1
            return True
        except (requests.exceptions.RequestException, ValueError) as e:
            logging.error(f"{timestamp} - 데이터 요청 실패: {e}")
            print(f"{timestamp} 데이터 요청 실패: {e}")
            time.sleep(5)  # 5초 후 재시도
    return False

# 기존에 수집된 데이터의 타임스탬프 목록 로드
existing_timestamps = load_existing_data()

# 전체 데이터 수집
for timestamp in time_points:
    if timestamp in existing_timestamps:
        print(f"{timestamp} 이미 데이터가 존재합니다. 건너뜁니다.")
        continue  # 이미 수집된 데이터는 건너뛰기
    
    if not fetch_weather_data(timestamp):
        break
    time.sleep(1)  # 과부하 방지를 위한 대기

# 데이터 CSV 저장
if data_list:
    df = pd.DataFrame(data_list)
    df.to_csv('weather_data.csv', index=False, encoding='utf-8-sig', mode='a', header=not bool(existing_timestamps))
    print("CSV 파일 저장 완료: weather_data.csv")
# Out:
# 202401010000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401010300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401010600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401010900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401011200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401011500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401011800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401012100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401020000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401020300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401020600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401020900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401021200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401021500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401021800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401022100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401030000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401030300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401030600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401030900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401031200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401031500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401031800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401032100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401040000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401040300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401040600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401040900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401041200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401041500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401041800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401042100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401050000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401050300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401050600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401050900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401051200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401051500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401051800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401052100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401060000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401060300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401060600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401060900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401061200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401061500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401061800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401062100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401070000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401070300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401070600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401070900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401071200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401071500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401071800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401072100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401080000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401080300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401080600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401080900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401081200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401081500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401081800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401082100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401090000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401090300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401090600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401090900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401091200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401091500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401091800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401092100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401100000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401100300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401100600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401100900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401101200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401101500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401101800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401102100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401110000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401110300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401110600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401110900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401111200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401111500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401111800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401112100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401120000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401120300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401120600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401120900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401121200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401121500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401121800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401122100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401130000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401130300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401130600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401130900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401131200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401131500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401131800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401132100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401140000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401140300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401140600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401140900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401141200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401141500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401141800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401142100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401150000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401150300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401150600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401150900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401151200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401151500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401151800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401152100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401160000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401160300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401160600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401160900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401161200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401161500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401161800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401162100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401170000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401170300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401170600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401170900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401171200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401171500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401171800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401172100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401180000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401180300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401180600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401180900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401181200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401181500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401181800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401182100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401190000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401190300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401190600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401190900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401191200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401191500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401191800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401192100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401200000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401200300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401200600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401200900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401201200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401201500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401201800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401202100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401210000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401210300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401210600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401210900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401211200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401211500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401211800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401212100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401220000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401220300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401220600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401220900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401221200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401221500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401221800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401222100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401230000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401230300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401230600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401230900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401231200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401231500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401231800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401232100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401240000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401240300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401240600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401240900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401241200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401241500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401241800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401242100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401250000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401250300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401250600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401250900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401251200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401251500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401251800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401252100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401260000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401260300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401260600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401260900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401261200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401261500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401261800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401262100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401270000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401270300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401270600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401270900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401271200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401271500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401271800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401272100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401280000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401280300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401280600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401280900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401281200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401281500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401281800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401282100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401290000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401290300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401290600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401290900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401291200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401291500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401291800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401292100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401300000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401300300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401300600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401300900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401301200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401301500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401301800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401302100 이미 데이터가 존재합니다. 건너뜁니다.
# 202401310000 이미 데이터가 존재합니다. 건너뜁니다.
# 202401310300 이미 데이터가 존재합니다. 건너뜁니다.
# 202401310600 이미 데이터가 존재합니다. 건너뜁니다.
# 202401310900 이미 데이터가 존재합니다. 건너뜁니다.
# 202401311200 이미 데이터가 존재합니다. 건너뜁니다.
# 202401311500 이미 데이터가 존재합니다. 건너뜁니다.
# 202401311800 이미 데이터가 존재합니다. 건너뜁니다.
# 202401312100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402010000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402010300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402010600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402010900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402011200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402011500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402011800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402012100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402020000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402020300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402020600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402020900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402021200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402021500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402021800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402022100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402030000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402030300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402030600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402030900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402031200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402031500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402031800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402032100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402040000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402040300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402040600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402040900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402041200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402041500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402041800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402042100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402050000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402050300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402050600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402050900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402051200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402051500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402051800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402052100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402060000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402060300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402060600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402060900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402061200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402061500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402061800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402062100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402070000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402070300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402070600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402070900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402071200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402071500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402071800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402072100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402080000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402080300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402080600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402080900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402081200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402081500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402081800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402082100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402090000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402090300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402090600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402090900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402091200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402091500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402091800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402092100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402100000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402100300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402100600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402100900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402101200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402101500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402101800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402102100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402110000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402110300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402110600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402110900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402111200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402111500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402111800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402112100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402120000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402120300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402120600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402120900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402121200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402121500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402121800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402122100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402130000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402130300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402130600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402130900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402131200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402131500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402131800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402132100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402140000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402140300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402140600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402140900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402141200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402141500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402141800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402142100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402150000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402150300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402150600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402150900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402151200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402151500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402151800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402152100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402160000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402160300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402160600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402160900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402161200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402161500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402161800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402162100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402170000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402170300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402170600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402170900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402171200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402171500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402171800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402172100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402180000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402180300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402180600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402180900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402181200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402181500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402181800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402182100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402190000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402190300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402190600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402190900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402191200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402191500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402191800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402192100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402200000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402200300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402200600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402200900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402201200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402201500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402201800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402202100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402210000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402210300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402210600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402210900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402211200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402211500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402211800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402212100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402220000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402220300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402220600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402220900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402221200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402221500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402221800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402222100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402230000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402230300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402230600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402230900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402231200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402231500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402231800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402232100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402240000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402240300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402240600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402240900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402241200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402241500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402241800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402242100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402250000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402250300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402250600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402250900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402251200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402251500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402251800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402252100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402260000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402260300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402260600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402260900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402261200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402261500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402261800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402262100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402270000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402270300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402270600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402270900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402271200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402271500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402271800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402272100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402280000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402280300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402280600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402280900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402281200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402281500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402281800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402282100 이미 데이터가 존재합니다. 건너뜁니다.
# 202402290000 이미 데이터가 존재합니다. 건너뜁니다.
# 202402290300 이미 데이터가 존재합니다. 건너뜁니다.
# 202402290600 이미 데이터가 존재합니다. 건너뜁니다.
# 202402290900 이미 데이터가 존재합니다. 건너뜁니다.
# 202402291200 이미 데이터가 존재합니다. 건너뜁니다.
# 202402291500 이미 데이터가 존재합니다. 건너뜁니다.
# 202402291800 이미 데이터가 존재합니다. 건너뜁니다.
# 202402292100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403010000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403010300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403010600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403010900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403011200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403011500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403011800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403012100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403020000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403020300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403020600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403020900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403021200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403021500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403021800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403022100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403030000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403030300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403030600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403030900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403031200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403031500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403031800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403032100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403040000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403040300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403040600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403040900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403041200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403041500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403041800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403042100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403050000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403050300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403050600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403050900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403051200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403051500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403051800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403052100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403060000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403060300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403060600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403060900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403061200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403061500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403061800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403062100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403070000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403070300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403070600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403070900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403071200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403071500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403071800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403072100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403080000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403080300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403080600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403080900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403081200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403081500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403081800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403082100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403090000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403090300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403090600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403090900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403091200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403091500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403091800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403092100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403100000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403100300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403100600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403100900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403101200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403101500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403101800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403102100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403110000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403110300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403110600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403110900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403111200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403111500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403111800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403112100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403120000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403120300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403120600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403120900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403121200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403121500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403121800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403122100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403130000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403130300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403130600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403130900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403131200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403131500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403131800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403132100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403140000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403140300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403140600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403140900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403141200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403141500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403141800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403142100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403150000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403150300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403150600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403150900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403151200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403151500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403151800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403152100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403160000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403160300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403160600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403160900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403161200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403161500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403161800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403162100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403170000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403170300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403170600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403170900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403171200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403171500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403171800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403172100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403180000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403180300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403180600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403180900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403181200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403181500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403181800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403182100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403190000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403190300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403190600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403190900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403191200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403191500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403191800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403192100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403200000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403200300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403200600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403200900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403201200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403201500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403201800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403202100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403210000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403210300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403210600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403210900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403211200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403211500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403211800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403212100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403220000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403220300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403220600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403220900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403221200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403221500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403221800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403222100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403230000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403230300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403230600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403230900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403231200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403231500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403231800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403232100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403240000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403240300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403240600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403240900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403241200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403241500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403241800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403242100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403250000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403250300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403250600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403250900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403251200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403251500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403251800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403252100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403260000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403260300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403260600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403260900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403261200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403261500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403261800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403262100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403270000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403270300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403270600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403270900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403271200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403271500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403271800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403272100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403280000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403280300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403280600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403280900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403281200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403281500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403281800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403282100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403290000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403290300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403290600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403290900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403291200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403291500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403291800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403292100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403300000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403300300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403300600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403300900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403301200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403301500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403301800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403302100 이미 데이터가 존재합니다. 건너뜁니다.
# 202403310000 이미 데이터가 존재합니다. 건너뜁니다.
# 202403310300 이미 데이터가 존재합니다. 건너뜁니다.
# 202403310600 이미 데이터가 존재합니다. 건너뜁니다.
# 202403310900 이미 데이터가 존재합니다. 건너뜁니다.
# 202403311200 이미 데이터가 존재합니다. 건너뜁니다.
# 202403311500 이미 데이터가 존재합니다. 건너뜁니다.
# 202403311800 이미 데이터가 존재합니다. 건너뜁니다.
# 202403312100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404010000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404010300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404010600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404010900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404011200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404011500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404011800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404012100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404020000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404020300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404020600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404020900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404021200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404021500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404021800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404022100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404030000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404030300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404030600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404030900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404031200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404031500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404031800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404032100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404040000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404040300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404040600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404040900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404041200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404041500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404041800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404042100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404050000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404050300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404050600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404050900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404051200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404051500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404051800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404052100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404060000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404060300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404060600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404060900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404061200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404061500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404061800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404062100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404070000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404070300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404070600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404070900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404071200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404071500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404071800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404072100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404080000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404080300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404080600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404080900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404081200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404081500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404081800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404082100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404090000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404090300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404090600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404090900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404091200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404091500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404091800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404092100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404100000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404100300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404100600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404100900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404101200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404101500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404101800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404102100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404110000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404110300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404110600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404110900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404111200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404111500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404111800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404112100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404120000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404120300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404120600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404120900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404121200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404121500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404121800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404122100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404130000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404130300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404130600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404130900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404131200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404131500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404131800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404132100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404140000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404140300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404140600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404140900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404141200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404141500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404141800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404142100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404150000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404150300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404150600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404150900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404151200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404151500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404151800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404152100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404160000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404160300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404160600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404160900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404161200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404161500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404161800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404162100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404170000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404170300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404170600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404170900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404171200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404171500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404171800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404172100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404180000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404180300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404180600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404180900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404181200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404181500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404181800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404182100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404190000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404190300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404190600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404190900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404191200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404191500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404191800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404192100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404200000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404200300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404200600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404200900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404201200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404201500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404201800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404202100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404210000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404210300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404210600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404210900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404211200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404211500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404211800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404212100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404220000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404220300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404220600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404220900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404221200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404221500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404221800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404222100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404230000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404230300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404230600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404230900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404231200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404231500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404231800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404232100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404240000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404240300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404240600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404240900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404241200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404241500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404241800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404242100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404250000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404250300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404250600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404250900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404251200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404251500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404251800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404252100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404260000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404260300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404260600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404260900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404261200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404261500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404261800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404262100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404270000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404270300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404270600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404270900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404271200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404271500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404271800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404272100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404280000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404280300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404280600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404280900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404281200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404281500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404281800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404282100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404290000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404290300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404290600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404290900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404291200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404291500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404291800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404292100 이미 데이터가 존재합니다. 건너뜁니다.
# 202404300000 이미 데이터가 존재합니다. 건너뜁니다.
# 202404300300 이미 데이터가 존재합니다. 건너뜁니다.
# 202404300600 이미 데이터가 존재합니다. 건너뜁니다.
# 202404300900 이미 데이터가 존재합니다. 건너뜁니다.
# 202404301200 이미 데이터가 존재합니다. 건너뜁니다.
# 202404301500 이미 데이터가 존재합니다. 건너뜁니다.
# 202404301800 이미 데이터가 존재합니다. 건너뜁니다.
# 202404302100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405010000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405010300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405010600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405010900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405011200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405011500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405011800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405012100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405020000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405020300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405020600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405020900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405021200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405021500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405021800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405022100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405030000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405030300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405030600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405030900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405031200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405031500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405031800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405032100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405040000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405040300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405040600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405040900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405041200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405041500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405041800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405042100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405050000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405050300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405050600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405050900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405051200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405051500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405051800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405052100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405060000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405060300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405060600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405060900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405061200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405061500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405061800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405062100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405070000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405070300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405070600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405070900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405071200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405071500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405071800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405072100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405080000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405080300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405080600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405080900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405081200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405081500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405081800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405082100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405090000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405090300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405090600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405090900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405091200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405091500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405091800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405092100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405100000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405100300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405100600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405100900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405101200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405101500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405101800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405102100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405110000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405110300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405110600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405110900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405111200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405111500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405111800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405112100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405120000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405120300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405120600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405120900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405121200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405121500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405121800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405122100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405130000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405130300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405130600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405130900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405131200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405131500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405131800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405132100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405140000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405140300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405140600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405140900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405141200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405141500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405141800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405142100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405150000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405150300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405150600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405150900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405151200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405151500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405151800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405152100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405160000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405160300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405160600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405160900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405161200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405161500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405161800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405162100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405170000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405170300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405170600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405170900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405171200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405171500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405171800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405172100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405180000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405180300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405180600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405180900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405181200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405181500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405181800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405182100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405190000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405190300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405190600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405190900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405191200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405191500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405191800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405192100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405200000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405200300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405200600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405200900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405201200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405201500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405201800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405202100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405210000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405210300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405210600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405210900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405211200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405211500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405211800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405212100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405220000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405220300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405220600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405220900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405221200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405221500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405221800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405222100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405230000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405230300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405230600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405230900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405231200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405231500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405231800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405232100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405240000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405240300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405240600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405240900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405241200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405241500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405241800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405242100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405250000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405250300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405250600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405250900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405251200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405251500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405251800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405252100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405260000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405260300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405260600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405260900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405261200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405261500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405261800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405262100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405270000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405270300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405270600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405270900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405271200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405271500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405271800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405272100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405280000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405280300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405280600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405280900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405281200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405281500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405281800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405282100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405290000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405290300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405290600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405290900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405291200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405291500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405291800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405292100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405300000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405300300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405300600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405300900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405301200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405301500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405301800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405302100 이미 데이터가 존재합니다. 건너뜁니다.
# 202405310000 이미 데이터가 존재합니다. 건너뜁니다.
# 202405310300 이미 데이터가 존재합니다. 건너뜁니다.
# 202405310600 이미 데이터가 존재합니다. 건너뜁니다.
# 202405310900 이미 데이터가 존재합니다. 건너뜁니다.
# 202405311200 이미 데이터가 존재합니다. 건너뜁니다.
# 202405311500 이미 데이터가 존재합니다. 건너뜁니다.
# 202405311800 이미 데이터가 존재합니다. 건너뜁니다.
# 202405312100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406010000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406010300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406010600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406010900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406011200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406011500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406011800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406012100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406020000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406020300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406020600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406020900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406021200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406021500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406021800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406022100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406030000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406030300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406030600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406030900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406031200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406031500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406031800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406032100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406040000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406040300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406040600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406040900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406041200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406041500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406041800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406042100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406050000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406050300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406050600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406050900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406051200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406051500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406051800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406052100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406060000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406060300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406060600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406060900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406061200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406061500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406061800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406062100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406070000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406070300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406070600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406070900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406071200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406071500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406071800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406072100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406080000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406080300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406080600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406080900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406081200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406081500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406081800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406082100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406090000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406090300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406090600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406090900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406091200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406091500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406091800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406092100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406100000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406100300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406100600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406100900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406101200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406101500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406101800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406102100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406110000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406110300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406110600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406110900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406111200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406111500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406111800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406112100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406120000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406120300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406120600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406120900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406121200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406121500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406121800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406122100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406130000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406130300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406130600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406130900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406131200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406131500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406131800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406132100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406140000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406140300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406140600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406140900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406141200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406141500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406141800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406142100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406150000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406150300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406150600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406150900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406151200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406151500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406151800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406152100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406160000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406160300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406160600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406160900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406161200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406161500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406161800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406162100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406170000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406170300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406170600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406170900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406171200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406171500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406171800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406172100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406180000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406180300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406180600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406180900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406181200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406181500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406181800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406182100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406190000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406190300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406190600 이미 데이터가 존재합니다. 건너뜁니다.
# 202406190900 이미 데이터가 존재합니다. 건너뜁니다.
# 202406191200 이미 데이터가 존재합니다. 건너뜁니다.
# 202406191500 이미 데이터가 존재합니다. 건너뜁니다.
# 202406191800 이미 데이터가 존재합니다. 건너뜁니다.
# 202406192100 이미 데이터가 존재합니다. 건너뜁니다.
# 202406200000 이미 데이터가 존재합니다. 건너뜁니다.
# 202406200300 이미 데이터가 존재합니다. 건너뜁니다.
# 202406200600 이미 데이터가 존재합니다. 건너뜁니다.
# ...
# 202411041200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411041500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411041800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411042100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411050000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411050300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411050600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411050900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411051200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411051500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411051800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411052100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411060000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411060300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411060600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411060900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411061200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411061500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411061800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411062100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411070000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411070300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411070600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411070900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411071200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411071500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411071800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411072100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411080000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411080300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411080600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411080900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411081200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411081500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411081800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411082100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411090000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411090300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411090600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411090900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411091200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411091500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411091800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411092100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411100000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411100300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411100600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411100900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411101200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411101500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411101800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411102100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411110000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411110300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411110600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411110900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411111200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411111500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411111800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411112100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411120000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411120300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411120600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411120900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411121200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411121500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411121800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411122100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411130000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411130300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411130600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411130900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411131200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411131500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411131800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411132100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411140000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411140300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411140600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411140900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411141200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411141500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411141800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411142100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411150000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411150300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411150600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411150900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411151200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411151500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411151800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411152100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411160000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411160300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411160600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411160900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411161200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411161500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411161800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411162100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411170000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411170300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411170600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411170900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411171200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411171500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411171800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411172100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411180000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411180300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411180600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411180900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411181200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411181500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411181800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411182100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411190000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411190300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411190600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411190900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411191200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411191500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411191800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411192100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411200000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411200300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411200600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411200900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411201200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411201500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411201800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411202100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411210000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411210300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411210600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411210900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411211200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411211500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411211800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411212100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411220000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411220300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411220600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411220900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411221200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411221500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411221800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411222100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411230000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411230300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411230600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411230900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411231200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411231500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411231800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411232100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411240000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411240300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411240600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411240900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411241200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411241500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411241800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411242100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411250000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411250300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411250600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411250900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411251200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411251500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411251800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411252100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411260000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411260300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411260600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411260900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411261200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411261500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411261800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411262100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411270000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411270300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411270600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411270900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411271200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411271500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411271800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411272100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411280000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411280300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411280600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411280900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411281200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411281500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411281800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411282100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411290000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411290300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411290600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411290900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411291200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411291500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411291800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411292100 이미 데이터가 존재합니다. 건너뜁니다.
# 202411300000 이미 데이터가 존재합니다. 건너뜁니다.
# 202411300300 이미 데이터가 존재합니다. 건너뜁니다.
# 202411300600 이미 데이터가 존재합니다. 건너뜁니다.
# 202411300900 이미 데이터가 존재합니다. 건너뜁니다.
# 202411301200 이미 데이터가 존재합니다. 건너뜁니다.
# 202411301500 이미 데이터가 존재합니다. 건너뜁니다.
# 202411301800 이미 데이터가 존재합니다. 건너뜁니다.
# 202411302100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412010000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412010300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412010600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412010900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412011200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412011500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412011800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412012100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412020000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412020300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412020600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412020900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412021200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412021500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412021800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412022100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412030000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412030300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412030600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412030900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412031200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412031500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412031800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412032100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412040000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412040300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412040600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412040900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412041200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412041500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412041800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412042100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412050000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412050300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412050600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412050900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412051200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412051500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412051800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412052100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412060000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412060300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412060600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412060900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412061200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412061500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412061800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412062100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412070000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412070300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412070600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412070900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412071200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412071500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412071800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412072100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412080000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412080300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412080600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412080900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412081200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412081500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412081800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412082100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412090000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412090300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412090600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412090900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412091200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412091500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412091800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412092100 데이터 수집 완료.
# 202412100000 데이터 수집 완료.
# 202412100300 데이터 수집 완료.
# 202412100600 데이터 수집 완료.
# 202412100900 데이터 수집 완료.
# 202412101200 데이터 수집 완료.
# 202412101500 데이터 수집 완료.
# 202412101800 데이터 수집 완료.
# 202412102100 데이터 수집 완료.
# 202412110000 데이터 수집 완료.
# 202412110300 데이터 수집 완료.
# 202412110600 데이터 수집 완료.
# 202412110900 데이터 수집 완료.
# 202412111200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412111500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412111800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412112100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412120000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412120300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412120600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412120900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412121200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412121500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412121800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412122100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412130000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412130300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412130600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412130900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412131200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412131500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412131800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412132100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412140000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412140300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412140600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412140900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412141200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412141500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412141800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412142100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412150000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412150300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412150600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412150900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412151200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412151500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412151800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412152100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412160000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412160300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412160600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412160900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412161200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412161500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412161800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412162100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412170000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412170300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412170600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412170900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412171200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412171500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412171800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412172100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412180000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412180300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412180600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412180900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412181200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412181500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412181800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412182100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412190000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412190300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412190600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412190900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412191200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412191500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412191800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412192100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412200000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412200300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412200600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412200900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412201200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412201500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412201800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412202100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412210000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412210300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412210600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412210900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412211200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412211500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412211800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412212100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412220000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412220300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412220600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412220900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412221200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412221500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412221800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412222100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412230000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412230300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412230600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412230900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412231200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412231500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412231800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412232100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412240000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412240300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412240600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412240900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412241200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412241500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412241800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412242100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412250000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412250300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412250600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412250900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412251200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412251500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412251800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412252100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412260000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412260300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412260600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412260900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412261200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412261500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412261800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412262100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412270000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412270300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412270600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412270900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412271200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412271500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412271800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412272100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412280000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412280300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412280600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412280900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412281200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412281500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412281800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412282100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412290000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412290300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412290600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412290900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412291200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412291500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412291800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412292100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412300000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412300300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412300600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412300900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412301200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412301500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412301800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412302100 이미 데이터가 존재합니다. 건너뜁니다.
# 202412310000 이미 데이터가 존재합니다. 건너뜁니다.
# 202412310300 이미 데이터가 존재합니다. 건너뜁니다.
# 202412310600 이미 데이터가 존재합니다. 건너뜁니다.
# 202412310900 이미 데이터가 존재합니다. 건너뜁니다.
# 202412311200 이미 데이터가 존재합니다. 건너뜁니다.
# 202412311500 이미 데이터가 존재합니다. 건너뜁니다.
# 202412311800 이미 데이터가 존재합니다. 건너뜁니다.
# 202412312100 이미 데이터가 존재합니다. 건너뜁니다.
# CSV 파일 저장 완료: weather_data.csv

# %% [markdown]
# ### 데이터 종합 끝
